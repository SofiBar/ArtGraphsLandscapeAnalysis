# %%
# !pip install SPARQLWrapper

from SPARQLWrapper import SPARQLWrapper, JSON
import ssl
import csv
import os
# Out:
# Requirement already satisfied: SPARQLWrapper in /usr/local/lib/python3.7/dist-packages (2.0.0)
# Requirement already satisfied: rdflib>=6.1.1 in /usr/local/lib/python3.7/dist-packages (from SPARQLWrapper) (6.1.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (3.0.8)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (0.6.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (4.11.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (57.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib>=6.1.1->SPARQLWrapper) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib>=6.1.1->SPARQLWrapper) (4.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from isodate->rdflib>=6.1.1->SPARQLWrapper) (1.15.0)

# %%
def sparl_query_setting(query, endpoint):# set the endpoint 
  sparql = SPARQLWrapper(endpoint)
  # set the query
  sparql.setQuery(query)
  # set the returned format
  sparql.setReturnFormat(JSON)
  # get the results
  results = sparql.query().convert()
  return results

# %%
def sample_selection(csv_to_create, query, endpoint, var_list): 
  with open(csv_to_create, mode='a') as my_file: 
    my_file = csv.writer(my_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_ALL)
    if os.stat(csv_to_create).st_size == 0:
        my_file.writerow(var_list)
    res = sparl_query_setting(query, endpoint)
    for result in res["results"]["bindings"]:
      result_list = []
      for var in var_list: 
        if var not in result: 
          new_var = "none"
        else:
          new_var = result[var]["value"]
        result_list.append(new_var)
      my_file.writerow(result_list)

# %%
finland = "http://ldf.fi/mufi/sparql"
cervantes = "http://data.cervantesvirtual.com/sparql"
es_cultura= "https://datos.bne.es/sparql"
nl_spain = "http://cultura.linkeddata.es/sparql"
nd_hungary = "https://lod.sztaki.hu/sparql"
smithsonian = "https://api.triplydb.com/datasets/smithsonian/american-art-museum/services/american-art-museum/sparql"
american_lod = "https://data.americanartcollaborative.org/sparql"
dbpedia = "https://dbpedia.org/sparql"
yago = "https://yago-knowledge.org/sparql/query"
sari_endpoint= "https://rds.swissartresearch.net/sparql"
arco_endpoint = "https://dati.beniculturali.it/sparql"
wd_endpoint = "https://query.wikidata.org/bigdata/namespace/wdq/sparql"
zeri_endpoint = "http://data.fondazionezeri.unibo.it/sparql"
mmm_endpoint = "http://ldf.fi/mmm/sparql"
nomisma_endpoint = "http://nomisma.org/query"
b3k_endpoint = "http://lod.b3kat.de/doc/sparql-endpoint"
bnf_endpoint = "https://data.bnf.fr/sparql"
euro = "http://sparql.europeana.eu/"
arco= "https://dati.cultura.gov.it/sparql"

# %% [markdown]
# # SEMANTIC VALIDITY SAMPLE

# %%
def makeatsv(filename, results, artwork, subject):
  with open(filename, 'wt') as out_file:
    tsv_writer = csv.writer(out_file, delimiter='\t')
    tsv_writer.writerow(['artwork', 'subject'])
    for result in results["results"]["bindings"]:
      tsv_writer.writerow([result[artwork]["value"], result[subject]["value"]])

# %% [markdown]
# ## DBpedia
#
# Take 50 random artwork-subject couples using the dbp:subject property
# Take 50 random artwork-subject couples using the dct:subject property

# %%
qmdb1 = '''
prefix dbo: <http://dbpedia.org/ontology/>
prefix dct: <http://purl.org/dc/terms/>
prefix dbp: <http://dbpedia.org/property/>
SELECT distinct ?artwork ?subject WHERE {
# ?artwork a dbo:Artwork;
dbp:subject ?subject .
}ORDER BY RAND()
LIMIT 50'''

qmdb2 = '''prefix dbo: <http://dbpedia.org/ontology/>
prefix dct: <http://purl.org/dc/terms/>
prefix dbp: <http://dbpedia.org/property/>
SELECT distinct ?artwork ?subject WHERE {
# ?artwork a dbo:Artwork;
dct:subject ?subject .
}ORDER BY RAND()
LIMIT 50'''

resmdb1 = sparl_query_setting(qmdb1, dbpedia)
resmdb2 = sparl_query_setting(qmdb2, dbpedia)

# %%
import csv

# %%
with open('dbpediasem.tsv', 'wt') as out_file:
    tsv_writer = csv.writer(out_file, delimiter='\t')
    tsv_writer.writerow(['artwork', 'subject'])
    for result in resmdb1["results"]["bindings"]:
      tsv_writer.writerow([result["artwork"]["value"], result["subject"]["value"]])
    for result2 in resmdb2["results"]["bindings"]:
      tsv_writer.writerow([result2["artwork"]["value"], result2["subject"]["value"]])

# %% [markdown]
# ## Europeana
#
# Take all the painting-subject triples (dc:subject)
# Take all the sculpture-subject triples (dc:subject)
#
# Randomly sample 100 triples from these two

# %%
qeuro1paint = '''PREFIX ore: <http://www.openarchives.org/ore/terms/>
PREFIX edm: <http://www.europeana.eu/schemas/edm/>

select  distinct ?CHO ?sub where {
             # ?s a <http://www.w3.org/2004/02/skos/core#Concept> ;
<http://www.w3.org/2004/02/skos/core#broader>* <http://vocab.getty.edu/aat/300033618> .
# ?CHO dc:type ?s ;
dc:subject ?sub 
}
'''

qeuro1sculpt= '''PREFIX ore: <http://www.openarchives.org/ore/terms/>
PREFIX edm: <http://www.europeana.eu/schemas/edm/>

select  distinct ?CHO ?sub where {
             # ?s a <http://www.w3.org/2004/02/skos/core#Concept> ;
              <http://www.w3.org/2004/02/skos/core#broader>* <http://vocab.getty.edu/aat/300047090> .
# ?CHO dc:type ?s ;
dc:subject ?sub }'''

reseuro1p = sparl_query_setting(qeuro1paint, euro)
reseuro1s = sparl_query_setting(qeuro1sculpt, euro)

# %%
paintings = []
for res in reseuro1p["results"]["bindings"]:
  artwork = res["CHO"]["value"]
  sub = res["sub"]["value"]
  paintings.append((artwork, sub))
print(len(paintings))
for res in reseuro1s["results"]["bindings"]:
  artwork = res["CHO"]["value"]
  sub = res["sub"]["value"]
  paintings.append((artwork, sub))
print(len(paintings))
# Out:
# 9273
# 10690

# %%
from random import sample
sampledartworks = sample(paintings, 100)

# %%
print(sampledartworks[:10])
# Out:
# [('http://data.europeana.eu/proxy/provider/2023006/24062A51_priref_16880', 'schilderingen'), ('http://data.europeana.eu/proxy/provider/2023006/24062A51_priref_16309', 'schilderingen'), ('http://data.europeana.eu/proxy/provider/90402/SK_A_3758', 'Batavia'), ('http://data.europeana.eu/proxy/provider/2048077/Athena_Plus_ProvidedCHO_Bildarchiv_Foto_Marburg_obj_20395264_fmd458543', 'die zwölf Apostel (als Gruppe), in der Regel mit Büchern oder Schriftrollen (nicht im biblischen Kontext), mit Paulus statt Judas'), ('http://data.europeana.eu/proxy/provider/2023009/23096B51_priref_10626', 'fiets'), ('http://data.europeana.eu/proxy/provider/2048077/Athena_Plus_ProvidedCHO_Bildarchiv_Foto_Marburg_obj_20318319_fmd455670', 'Musikinstrumente; Gruppe von Musikinstrumenten'), ('http://data.europeana.eu/proxy/provider/90402/SK_A_742', 'http://iconclass.org/25F29(ARMADILLO)'), ('http://data.europeana.eu/proxy/provider/2026116/Partage_Plus_ProvidedCHO_Bildarchiv_Foto_Marburg_t2_20065140_fmd474022', 'http://iconclass.org/11G'), ('http://data.europeana.eu/proxy/provider/90402/SK_A_4624', 'Vliet, Adriaen van der'), ('http://data.europeana.eu/proxy/provider/2023006/24062A51_priref_16896', 'schilderingen')]

# %%
import csv
with open("europeanasemantic.tsv", "wt") as out_file:
  twriter = csv.writer(out_file, delimiter="\t")
  twriter.writerow(["artwork", "subject"])
  for artsub in sampledartworks:
    art = artsub[0]
    sub = artsub[1]
    twriter.writerow([art, sub])

# %% [markdown]
# ## Yago

# %%
qy1 = '''
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>

SELECT distinct ?artwork ?sub
WHERE {
  VALUES ?art {schema:Painting schema:Sculpture}
  # ?artwork rdf:type ?art ;
  schema:about ?sub 
}ORDER BY RAND()
LIMIT 100'''
ry1 = sparl_query_setting(qy1, yago)

# %%
makeatsv("yago.tsv", ry1, "artwork", "sub")

# %% [markdown]
# ## ND HUNGARY
#
# 500 results per query max, no random
#
# Do 100 queries for artwork subject with random offset from 1 to 39441
# (total number of subjects)

# %%
querynd = '''SELECT COUNT(?sub) as ?tot WHERE {
# ?URI <http://purl.org/dc/terms/type> dcmitype:Image ;
<http://purl.org/dc/terms/subject> ?sub .
 }'''

rndh = sparl_query_setting(querynd, nd_hungary)
for result in rndh["results"]["bindings"]:
  print(result["tot"]["value"])
# Out:
# 39441

# %%
import random
resultsnd = set()
queryndsample = '''SELECT ?URI ?sub WHERE {
# ?URI <http://purl.org/dc/terms/type> dcmitype:Image ;
<http://purl.org/dc/terms/subject> ?sub .
 }LIMIT 1
 OFFSET @@n@@'''
while len(resultsnd) < 100:
  randomn = random.randint(0, 39440)
  queryndrandom = queryndsample.replace("@@n@@", str(randomn))
  rndhsem = sparl_query_setting(queryndrandom, nd_hungary)
  for res in rndhsem["results"]["bindings"]:
    art = res["URI"]["value"]
    sub = res["sub"]["value"]
    resultsnd.add((art, sub))

# %%
len(resultsnd)
# Out:
# 100

# %%
resultsnd
# Out:
# {('http://lod.sztaki.hu/data/item/10060', 'fa'),
#  ('http://lod.sztaki.hu/data/item/10131', 'emberábrázolás'),
#  ('http://lod.sztaki.hu/data/item/10142', 'magyar'),
#  ('http://lod.sztaki.hu/data/item/10282', 'fénykép'),
#  ('http://lod.sztaki.hu/data/item/10507', 'eredeti'),
#  ('http://lod.sztaki.hu/data/item/10553', 'grafika'),
#  ('http://lod.sztaki.hu/data/item/10589', 'magyar'),
#  ('http://lod.sztaki.hu/data/item/10610', 'eredeti'),
#  ('http://lod.sztaki.hu/data/item/10629', 'rézkarc'),
#  ('http://lod.sztaki.hu/data/item/10841', 'emberábrázolás'),
#  ('http://lod.sztaki.hu/data/item/10926', 'grafika'),
#  ('http://lod.sztaki.hu/data/item/11113', 'magyar'),
#  ('http://lod.sztaki.hu/data/item/11147', '1973-1989'),
#  ('http://lod.sztaki.hu/data/item/11175', 'grafika'),
#  ('http://lod.sztaki.hu/data/item/11219', 'rézkarc'),
#  ('http://lod.sztaki.hu/data/item/11306', 'rézkarc'),
#  ('http://lod.sztaki.hu/data/item/11327', 'akt'),
#  ('http://lod.sztaki.hu/data/item/11347', 'ceruzarajz'),
#  ('http://lod.sztaki.hu/data/item/11719', 'litográfia'),
#  ('http://lod.sztaki.hu/data/item/11816', 'linóleummetszet'),
#  ('http://lod.sztaki.hu/data/item/11826', 'eredeti'),
#  ('http://lod.sztaki.hu/data/item/11884', 'linóleummetszet'),
#  ('http://lod.sztaki.hu/data/item/11981', 'grafika'),
#  ('http://lod.sztaki.hu/data/item/11981', 'magyar'),
#  ('http://lod.sztaki.hu/data/item/12038', 'grafika'),
#  ('http://lod.sztaki.hu/data/item/12102', 'eredeti'),
#  ('http://lod.sztaki.hu/data/item/12121', 'magyar'),
#  ('http://lod.sztaki.hu/data/item/12348', 'magyar'),
#  ('http://lod.sztaki.hu/data/item/12387', 'Radnóti Miklós (1909-1944)'),
#  ('http://lod.sztaki.hu/data/item/12486', 'grafika'),
#  ('http://lod.sztaki.hu/data/item/6216', 'fotóművészet'),
#  ('http://lod.sztaki.hu/data/item/6294', 'eredeti'),
#  ('http://lod.sztaki.hu/data/item/6446', 'eredeti'),
#  ('http://lod.sztaki.hu/data/item/6483', 'eredeti'),
#  ('http://lod.sztaki.hu/data/item/6537', 'fénykép'),
#  ('http://lod.sztaki.hu/data/item/6576', 'magyar'),
#  ('http://lod.sztaki.hu/data/item/6677', 'grafika'),
#  ('http://lod.sztaki.hu/data/item/6757', 'linóleummetszet'),
#  ('http://lod.sztaki.hu/data/item/6788', 'emberábrázolás'),
#  ('http://lod.sztaki.hu/data/item/6798', 'város'),
#  ('http://lod.sztaki.hu/data/item/6860', 'magyar'),
#  ('http://lod.sztaki.hu/data/item/6926', '1921-1929'),
#  ('http://lod.sztaki.hu/data/item/7007', 'eredeti'),
#  ('http://lod.sztaki.hu/data/item/7067', 'hidegtű'),
#  ('http://lod.sztaki.hu/data/item/7078', 'eredeti'),
#  ('http://lod.sztaki.hu/data/item/7155', 'eredeti'),
#  ('http://lod.sztaki.hu/data/item/7164', 'kréta'),
#  ('http://lod.sztaki.hu/data/item/7227', 'nőábrázolás'),
#  ('http://lod.sztaki.hu/data/item/7291', 'magyar'),
#  ('http://lod.sztaki.hu/data/item/7388', '1931-1949'),
#  ('http://lod.sztaki.hu/data/item/7456', 'magyar'),
#  ('http://lod.sztaki.hu/data/item/7463', 'rézkarc'),
#  ('http://lod.sztaki.hu/data/item/7520', '1931-1949'),
#  ('http://lod.sztaki.hu/data/item/7571', 'grafika'),
#  ('http://lod.sztaki.hu/data/item/7575', 'világháború, II.'),
#  ('http://lod.sztaki.hu/data/item/7593', '1931-1949'),
#  ('http://lod.sztaki.hu/data/item/7653', 'nőábrázolás'),
#  ('http://lod.sztaki.hu/data/item/7686', 'eredeti'),
#  ('http://lod.sztaki.hu/data/item/7692', 'linóleummetszet'),
#  ('http://lod.sztaki.hu/data/item/7738', '1931-1949'),
#  ('http://lod.sztaki.hu/data/item/7808', 'eredeti'),
#  ('http://lod.sztaki.hu/data/item/7853', 'hidegtű'),
#  ('http://lod.sztaki.hu/data/item/7952', 'eredeti'),
#  ('http://lod.sztaki.hu/data/item/7989', 'ábrázolása'),
#  ('http://lod.sztaki.hu/data/item/8011', 'magyar'),
#  ('http://lod.sztaki.hu/data/item/8036', 'arckép'),
#  ('http://lod.sztaki.hu/data/item/8118', 'eredeti'),
#  ('http://lod.sztaki.hu/data/item/8185', 'város'),
#  ('http://lod.sztaki.hu/data/item/8203', 'rézkarc'),
#  ('http://lod.sztaki.hu/data/item/8301', 'grafika'),
#  ('http://lod.sztaki.hu/data/item/8361', 'fametszet'),
#  ('http://lod.sztaki.hu/data/item/8375', 'grafika'),
#  ('http://lod.sztaki.hu/data/item/8392', '1930'),
#  ('http://lod.sztaki.hu/data/item/8436', 'eredeti'),
#  ('http://lod.sztaki.hu/data/item/8581', 'grafika'),
#  ('http://lod.sztaki.hu/data/item/8704', '19. század vége'),
#  ('http://lod.sztaki.hu/data/item/8736', 'nőábrázolás'),
#  ('http://lod.sztaki.hu/data/item/8813', 'szénrajz'),
#  ('http://lod.sztaki.hu/data/item/8853', '19. század második fele'),
#  ('http://lod.sztaki.hu/data/item/8904', 'textil'),
#  ('http://lod.sztaki.hu/data/item/8941', 'grafika'),
#  ('http://lod.sztaki.hu/data/item/9010', 'növényábrázolás'),
#  ('http://lod.sztaki.hu/data/item/9043', '1855'),
#  ('http://lod.sztaki.hu/data/item/9141', 'magyar'),
#  ('http://lod.sztaki.hu/data/item/9233', 'grafika'),
#  ('http://lod.sztaki.hu/data/item/9285', 'gyümölcsábrázolás'),
#  ('http://lod.sztaki.hu/data/item/9300', 'arckép'),
#  ('http://lod.sztaki.hu/data/item/9303', 'grafika'),
#  ('http://lod.sztaki.hu/data/item/9314', 'eredeti'),
#  ('http://lod.sztaki.hu/data/item/9371', 'eredeti'),
#  ('http://lod.sztaki.hu/data/item/9423', 'grafika'),
#  ('http://lod.sztaki.hu/data/item/9556', 'eredeti'),
#  ('http://lod.sztaki.hu/data/item/9578', 'szobrászat'),
#  ('http://lod.sztaki.hu/data/item/9604', 'fotóművészet'),
#  ('http://lod.sztaki.hu/data/item/9649', 'építészet'),
#  ('http://lod.sztaki.hu/data/item/9661', 'fotóművészet'),
#  ('http://lod.sztaki.hu/data/item/9692', 'eredeti'),
#  ('http://lod.sztaki.hu/data/item/9705', 'fotóművészet'),
#  ('http://lod.sztaki.hu/data/item/9879', 'eredeti'),
#  ('http://lod.sztaki.hu/data/item/9951', '1906-1914')}

# %%
with open("nd_hungarysem.tsv", "wt") as out_file:
  twriter = csv.writer(out_file, delimiter="\t")
  twriter.writerow(["artwork", "subject"])
  for artsub in resultsnd:
    art = artsub[0]
    sub = artsub[1]
    twriter.writerow([art, sub])

# %% [markdown]
# ## Zeri

# %%
# zeri
variables = ["art", "art_label", "subj", "subj_label"]
zeri_query = """

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX oaentry: <http://purl.org/emmedi/oaentry/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX fabio: <http://purl.org/spar/fabio/>

SELECT distinct ?art (sample(?a_label) as ?art_label) (sample(?s) as ?subj) ?subj_label
WHERE {
  # ?art a fabio:ArtisticWork. 
    # ?art fabio:hasSubjectTerm ?s; rdfs:label ?a_label.
  # ?s rdfs:label ?subj_label.
  }
  GROUP BY ?art ?subj_label
  ORDER BY RAND()
  LIMIT 100
  """


zeri_recall = sample_selection("semantic_validity_zeri.csv", zeri_query, zeri_endpoint, variables)

# %% [markdown]
# ## Nomisma

# %%
# nomisma
variables = ["art", "art_label", "subj", "subj_label"]
nomisma_query = """
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX dcmitype: <http://purl.org/dc/dcmitype/>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
PREFIX nm: <http://nomisma.org/id/>
PREFIX nmo: <http://nomisma.org/ontology#>
PREFIX org: <http://www.w3.org/ns/org#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>


SELECT DISTINCT ?art ?art_label (sample(?s) as ?subj)  ?subj_label WHERE {
  
 {?coin nmo:hasObverse ?art; skos:prefLabel ?art_label} UNION {?coin nmo:hasReverse ?art; skos:prefLabel ?art_label}
  # ?art nmo:hasPortrait ?s.
  # ?s skos:prefLabel ?subj_label.
  FILTER(lang(?art_label)='en')
  FILTER(lang(?subj_label)='en')
  
} GROUP BY ?art ?art_label ?subj_label
  ORDER BY RAND()
  LIMIT 100


"""


nomisma_recall = sample_selection("semantic_validity_nomisma.csv", nomisma_query, nomisma_endpoint, variables)

# %% [markdown]
# ## Wikidata

# %%
# wikidata
variables = ["art", "s"]
wd_query1 = """

SELECT  DISTINCT ?art ?s WHERE {
  # SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
  {?art wdt:P31 wd:Q3305213} UNION {?art wdt:P31 wd:Q860861}
  # ?art wdt:P180 ?s.
  
} 
  ORDER BY RAND()

  LIMIT 34


"""
wd_query2 = """

SELECT  DISTINCT ?art ?s WHERE {
  # SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
  {?art wdt:P31 wd:Q3305213} UNION {?art wdt:P31 wd:Q860861}
  # ?art wdt:P921 ?s.
  
} 
  ORDER BY RAND()

  LIMIT 33


"""
wd_query3 = """

SELECT  DISTINCT ?art ?s WHERE {
  # SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
  {?art wdt:P31 wd:Q3305213} UNION {?art wdt:P31 wd:Q860861}
  # ?art wdt:P1257 ?s.
  
} 
  ORDER BY RAND()

  LIMIT 33


"""

recall1 = sample_selection("semantic_validity3_wd.csv", wd_query1, wd_endpoint, variables)
recall2 = sample_selection("semantic_validity3_wd.csv", wd_query2, wd_endpoint, variables)

# %%
triples_list = []

wd_query = """

SELECT DISTINCT ?art ?s WHERE {
  # SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
  {?art wdt:P31 wd:Q3305213} UNION {?art wdt:P31 wd:Q860861}
  # ?art wdt:P1257 ?s.
  
} 
  ORDER BY RAND()



"""
res = sparl_query_setting(wd_query, wd_endpoint)

for result in res["results"]["bindings"]:
    triple = (result["art"]["value"], result["s"]["value"])
    print(triple)
    triples_list.append(triple)
# Out:
# Output streaming troncato alle ultime 5000 righe.
# ('http://www.wikidata.org/entity/Q28002591', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28002669', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28002683', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28002686', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28002086', '41D2663(+8)')
# ('http://www.wikidata.org/entity/Q28002113', '31D15(+822)')
# ('http://www.wikidata.org/entity/Q28002117', '31D15(+822)')
# ('http://www.wikidata.org/entity/Q28002136', '43A(+2)')
# ('http://www.wikidata.org/entity/Q28002628', '43A35')
# ('http://www.wikidata.org/entity/Q28002910', '31D15(+822)')
# ('http://www.wikidata.org/entity/Q28002912', '31D14(+812)')
# ('http://www.wikidata.org/entity/Q28002925', '41D222(+8)')
# ('http://www.wikidata.org/entity/Q28003037', '43B312')
# ('http://www.wikidata.org/entity/Q28003175', '34B2332(+982)')
# ('http://www.wikidata.org/entity/Q28003206', '31D15(+822)')
# ('http://www.wikidata.org/entity/Q28003233', '32B34')
# ('http://www.wikidata.org/entity/Q28003234', '41D26612')
# ('http://www.wikidata.org/entity/Q28003251', '31D14(+812)')
# ('http://www.wikidata.org/entity/Q28003293', '41D2663(+8)')
# ('http://www.wikidata.org/entity/Q28003980', '34B2332(+982)')
# ('http://www.wikidata.org/entity/Q28004005', '41D26612')
# ('http://www.wikidata.org/entity/Q28004007', '41D26612')
# ('http://www.wikidata.org/entity/Q28004064', '41D2663(+8)')
# ('http://www.wikidata.org/entity/Q28004456', '32B34')
# ('http://www.wikidata.org/entity/Q28004657', '31D16(+52)')
# ('http://www.wikidata.org/entity/Q28004659', '41D26612')
# ('http://www.wikidata.org/entity/Q28004666', '41D(+5)')
# ('http://www.wikidata.org/entity/Q28004731', '43A422')
# ('http://www.wikidata.org/entity/Q28004750', '41AA32')
# ('http://www.wikidata.org/entity/Q28004752', '33C2')
# ('http://www.wikidata.org/entity/Q28005357', '31D16(+52)')
# ('http://www.wikidata.org/entity/Q28005369', '41D2663(+8)')
# ('http://www.wikidata.org/entity/Q28005635', '41D222(+8)')
# ('http://www.wikidata.org/entity/Q28005671', '31D14(+812)')
# ('http://www.wikidata.org/entity/Q28005692', '41D(+5)')
# ('http://www.wikidata.org/entity/Q28005761', '31D15(+822)')
# ('http://www.wikidata.org/entity/Q28006066', '43A31')
# ('http://www.wikidata.org/entity/Q28006144', '41D222(+8)')
# ('http://www.wikidata.org/entity/Q28006313', '41A162')
# ('http://www.wikidata.org/entity/Q28006316', '42A411')
# ('http://www.wikidata.org/entity/Q28006482', '41D221(+8)')
# ('http://www.wikidata.org/entity/Q28006807', '42A411')
# ('http://www.wikidata.org/entity/Q28006818', '41C322')
# ('http://www.wikidata.org/entity/Q28007030', '41D2663(+8)')
# ('http://www.wikidata.org/entity/Q28007065', '32B34')
# ('http://www.wikidata.org/entity/Q28007090', '31D15(+822)')
# ('http://www.wikidata.org/entity/Q28007192', '41D26612')
# ('http://www.wikidata.org/entity/Q28007274', '41D222(+8)')
# ('http://www.wikidata.org/entity/Q28007483', '41D221(+8)')
# ('http://www.wikidata.org/entity/Q28007756', '41D26612')
# ('http://www.wikidata.org/entity/Q28007805', '42B761')
# ('http://www.wikidata.org/entity/Q28007910', '41D222(+8)')
# ('http://www.wikidata.org/entity/Q28008081', '41D222(+8)')
# ('http://www.wikidata.org/entity/Q28008104', '41AA32')
# ('http://www.wikidata.org/entity/Q28008238', '42A411')
# ('http://www.wikidata.org/entity/Q28008356', '41D222(+8)')
# ('http://www.wikidata.org/entity/Q28008443', '41D2663(+8)')
# ('http://www.wikidata.org/entity/Q28008634', '33A2')
# ('http://www.wikidata.org/entity/Q28008859', '41D222(+8)')
# ('http://www.wikidata.org/entity/Q28009151', '41C322')
# ('http://www.wikidata.org/entity/Q28009355', '31D14(+812)')
# ('http://www.wikidata.org/entity/Q28009409', '31D15(+822)')
# ('http://www.wikidata.org/entity/Q28009410', '31D15(+822)')
# ('http://www.wikidata.org/entity/Q28009420', '41B313')
# ('http://www.wikidata.org/entity/Q28009554', '31D15(+822)')
# ('http://www.wikidata.org/entity/Q28009657', '33C2')
# ('http://www.wikidata.org/entity/Q28011948', '41A622')
# ('http://www.wikidata.org/entity/Q28015403', '31D15(+822)')
# ('http://www.wikidata.org/entity/Q28015707', '31E23(+7)')
# ('http://www.wikidata.org/entity/Q28015708', '31E23(+7)')
# ('http://www.wikidata.org/entity/Q28015711', '31E23(+7)')
# ('http://www.wikidata.org/entity/Q28016024', '41A622')
# ('http://www.wikidata.org/entity/Q28016047', '41D2632')
# ('http://www.wikidata.org/entity/Q28016049', '41D2632')
# ('http://www.wikidata.org/entity/Q58442346', '31D15(+822)')
# ('http://www.wikidata.org/entity/Q111754146', '41A162')
# ('http://www.wikidata.org/entity/Q496966', '11H(BERNARDINO)')
# ('http://www.wikidata.org/entity/Q2246489', '73C311')
# ('http://www.wikidata.org/entity/Q2664637', '73D411')
# ('http://www.wikidata.org/entity/Q3157389', '73D411')
# ('http://www.wikidata.org/entity/Q3615317', '73D411')
# ('http://www.wikidata.org/entity/Q3951391', '71C31211')
# ('http://www.wikidata.org/entity/Q3974456', '71D11')
# ('http://www.wikidata.org/entity/Q4445298', '73D322')
# ('http://www.wikidata.org/entity/Q11690349', '73D322')
# ('http://www.wikidata.org/entity/Q17324950', '11H(MARTIN)')
# ('http://www.wikidata.org/entity/Q17328525', '73D322')
# ('http://www.wikidata.org/entity/Q17331780', '11H(MARTIN)')
# ('http://www.wikidata.org/entity/Q17630850', '71C31211')
# ('http://www.wikidata.org/entity/Q18508789', '11D331')
# ('http://www.wikidata.org/entity/Q18573206', '73D411')
# ('http://www.wikidata.org/entity/Q18573219', '73D411')
# ('http://www.wikidata.org/entity/Q18573678', '73D411')
# ('http://www.wikidata.org/entity/Q18599189', '73D411')
# ('http://www.wikidata.org/entity/Q18618731', '73C421')
# ('http://www.wikidata.org/entity/Q18629756', '11H(BERNARDINO)')
# ('http://www.wikidata.org/entity/Q18683177', '73D322')
# ('http://www.wikidata.org/entity/Q18683388', '11D331')
# ('http://www.wikidata.org/entity/Q18684704', '71W3141')
# ('http://www.wikidata.org/entity/Q18685752', '11H(BERNARDINO)')
# ('http://www.wikidata.org/entity/Q18685752', '11H(DONATUS)')
# ('http://www.wikidata.org/entity/Q18685752', '11H(MARTIN)')
# ('http://www.wikidata.org/entity/Q18686979', '71F373')
# ('http://www.wikidata.org/entity/Q18687784', '73D3512(+3)')
# ('http://www.wikidata.org/entity/Q28002109', '25G3(INDIAN BANYAN)(+29)')
# ('http://www.wikidata.org/entity/Q28002437', '25A22')
# ('http://www.wikidata.org/entity/Q28002477', '31AA2422')
# ('http://www.wikidata.org/entity/Q28002509', '31D16(+4)')
# ('http://www.wikidata.org/entity/Q28002576', '11Q0(+131)')
# ('http://www.wikidata.org/entity/Q28002928', '25F33(EAGLE)(+52)')
# ('http://www.wikidata.org/entity/Q28002935', '11Q71444')
# ('http://www.wikidata.org/entity/Q28003201', '31B62141')
# ('http://www.wikidata.org/entity/Q28003298', '34A43')
# ('http://www.wikidata.org/entity/Q28003493', '33C233')
# ('http://www.wikidata.org/entity/Q28004083', '25H154')
# ('http://www.wikidata.org/entity/Q28004112', '41A681')
# ('http://www.wikidata.org/entity/Q28004261', '31A2725')
# ('http://www.wikidata.org/entity/Q28004489', '31D16(+4)')
# ('http://www.wikidata.org/entity/Q28004555', '31AA2422')
# ('http://www.wikidata.org/entity/Q28004569', '11QQ622')
# ('http://www.wikidata.org/entity/Q28004638', '25I8')
# ('http://www.wikidata.org/entity/Q28004679', '31D16(+4)')
# ('http://www.wikidata.org/entity/Q28004873', '25H154')
# ('http://www.wikidata.org/entity/Q28004899', '31D16(+4)')
# ('http://www.wikidata.org/entity/Q28005187', '23Q1')
# ('http://www.wikidata.org/entity/Q28005237', '33C233')
# ('http://www.wikidata.org/entity/Q28005583', '31A45231')
# ('http://www.wikidata.org/entity/Q28005612', '23S13')
# ('http://www.wikidata.org/entity/Q28005789', '41A681')
# ('http://www.wikidata.org/entity/Q28005915', '31B62141')
# ('http://www.wikidata.org/entity/Q28005933', '31D16(+4)')
# ('http://www.wikidata.org/entity/Q28005944', '31D16(+4)')
# ('http://www.wikidata.org/entity/Q28006132', '24A8')
# ('http://www.wikidata.org/entity/Q28006135', '24A8')
# ('http://www.wikidata.org/entity/Q28006146', '25D3')
# ('http://www.wikidata.org/entity/Q28006223', '25D3')
# ('http://www.wikidata.org/entity/Q28006334', '41A681')
# ('http://www.wikidata.org/entity/Q28006345', '41A7751')
# ('http://www.wikidata.org/entity/Q28006347', '31A350')
# ('http://www.wikidata.org/entity/Q28006362', '25H154')
# ('http://www.wikidata.org/entity/Q28006470', '31A3111')
# ('http://www.wikidata.org/entity/Q28006496', '25G21(GOURD)')
# ('http://www.wikidata.org/entity/Q28006502', '25G41(POPPY)')
# ('http://www.wikidata.org/entity/Q28006506', '25G21(GOURD)')
# ('http://www.wikidata.org/entity/Q28006758', '26C31')
# ('http://www.wikidata.org/entity/Q28006851', '41A636')
# ('http://www.wikidata.org/entity/Q28006857', '25F(+46)')
# ('http://www.wikidata.org/entity/Q28007502', '34A43')
# ('http://www.wikidata.org/entity/Q28008233', '23S13')
# ('http://www.wikidata.org/entity/Q28008535', '25H154')
# ('http://www.wikidata.org/entity/Q28008624', '25A22')
# ('http://www.wikidata.org/entity/Q28008640', '31A2351(+55)')
# ('http://www.wikidata.org/entity/Q28008707', '31D16(+4)')
# ('http://www.wikidata.org/entity/Q28008745', '41A251')
# ('http://www.wikidata.org/entity/Q28008893', '11Q758')
# ('http://www.wikidata.org/entity/Q28008920', '41A7')
# ('http://www.wikidata.org/entity/Q28009043', '25F6(+523)')
# ('http://www.wikidata.org/entity/Q28009047', '33C233')
# ('http://www.wikidata.org/entity/Q28009102', '25D15')
# ('http://www.wikidata.org/entity/Q28009113', '23Q1')
# ('http://www.wikidata.org/entity/Q28009357', '31D11211')
# ('http://www.wikidata.org/entity/Q28009536', '41A636')
# ('http://www.wikidata.org/entity/Q28015706', '25A22')
# ('http://www.wikidata.org/entity/Q28016026', '41A636')
# ('http://www.wikidata.org/entity/Q58374493', '31A3111')
# ('http://www.wikidata.org/entity/Q58413087', '34B21(+21)')
# ('http://www.wikidata.org/entity/Q58413198', '25H154')
# ('http://www.wikidata.org/entity/Q58427217', '33C233')
# ('http://www.wikidata.org/entity/Q92386147', '25F72(MUSSEL)')
# ('http://www.wikidata.org/entity/Q111737603', '25D3')
# ('http://www.wikidata.org/entity/Q735061', '48C514')
# ('http://www.wikidata.org/entity/Q4373336', '41D262')
# ('http://www.wikidata.org/entity/Q5227835', '33A35')
# ('http://www.wikidata.org/entity/Q9019441', '48C514')
# ('http://www.wikidata.org/entity/Q11821336', '73B56')
# ('http://www.wikidata.org/entity/Q17319633', '43A(+71)')
# ('http://www.wikidata.org/entity/Q17319633', '43C911')
# ('http://www.wikidata.org/entity/Q17319907', '46C13143')
# ('http://www.wikidata.org/entity/Q17319998', '45C22')
# ('http://www.wikidata.org/entity/Q17319999', '45C22')
# ('http://www.wikidata.org/entity/Q17320010', '34B232(+964)')
# ('http://www.wikidata.org/entity/Q17320010', '42F2')
# ('http://www.wikidata.org/entity/Q17320010', '47B1814(+0)')
# ('http://www.wikidata.org/entity/Q17320057', '46B111')
# ('http://www.wikidata.org/entity/Q17320344', '46C181')
# ('http://www.wikidata.org/entity/Q17320394', '48C5212')
# ('http://www.wikidata.org/entity/Q17320895', '31E23621')
# ('http://www.wikidata.org/entity/Q17320952', '48C514')
# ('http://www.wikidata.org/entity/Q17321579', '92B3411')
# ('http://www.wikidata.org/entity/Q17322022', '71D1441')
# ('http://www.wikidata.org/entity/Q17322022', '71H5263')
# ('http://www.wikidata.org/entity/Q17322022', '73B56')
# ('http://www.wikidata.org/entity/Q17322114', '41D262')
# ('http://www.wikidata.org/entity/Q17322898', '71A342')
# ('http://www.wikidata.org/entity/Q17323007', '25F711(BEETLE)')
# ('http://www.wikidata.org/entity/Q17323007', '25F711(FLY)')
# ('http://www.wikidata.org/entity/Q17323056', '25G41(TULIP)')
# ('http://www.wikidata.org/entity/Q17324149', '41C22')
# ('http://www.wikidata.org/entity/Q17324149', '41C2541')
# ('http://www.wikidata.org/entity/Q17324149', '73C7223')
# ('http://www.wikidata.org/entity/Q17324215', '73E425')
# ('http://www.wikidata.org/entity/Q17324222', '71C3232')
# ('http://www.wikidata.org/entity/Q17324276', '25G41(NARCISSUS)')
# ('http://www.wikidata.org/entity/Q17324276', '25G41(TULIP)')
# ('http://www.wikidata.org/entity/Q17492749', '73C8613')
# ('http://www.wikidata.org/entity/Q17522663', '73C8613')
# ('http://www.wikidata.org/entity/Q18748328', '73C8122')
# ('http://www.wikidata.org/entity/Q18748399', '73B82(+3)')
# ('http://www.wikidata.org/entity/Q18761469', '73F1544')
# ('http://www.wikidata.org/entity/Q19318713', '11C23(+3)')
# ('http://www.wikidata.org/entity/Q19369234', '73C8613')
# ('http://www.wikidata.org/entity/Q19689027', '71C11932')
# ('http://www.wikidata.org/entity/Q19858206', '73A13')
# ('http://www.wikidata.org/entity/Q19858240', '73C222')
# ('http://www.wikidata.org/entity/Q19858273', '11H(MATTHEW)9')
# ('http://www.wikidata.org/entity/Q19858278', '73C7121')
# ('http://www.wikidata.org/entity/Q19858281', '73C313')
# ('http://www.wikidata.org/entity/Q19858295', '73C1336')
# ('http://www.wikidata.org/entity/Q19858305', '73C7121')
# ('http://www.wikidata.org/entity/Q19858314', '71L18321')
# ('http://www.wikidata.org/entity/Q19858358', '73D341')
# ('http://www.wikidata.org/entity/Q19858360', '73D325')
# ('http://www.wikidata.org/entity/Q19858362', '73D325')
# ('http://www.wikidata.org/entity/Q19858392', '73DD644')
# ('http://www.wikidata.org/entity/Q19858406', '73E21')
# ('http://www.wikidata.org/entity/Q19858675', '73C433')
# ('http://www.wikidata.org/entity/Q19858682', '73C8122')
# ('http://www.wikidata.org/entity/Q19858691', '73C433')
# ('http://www.wikidata.org/entity/Q19858703', '73C721')
# ('http://www.wikidata.org/entity/Q19858712', '73C721')
# ('http://www.wikidata.org/entity/Q19858725', '73C8613')
# ('http://www.wikidata.org/entity/Q19858733', '73D26')
# ('http://www.wikidata.org/entity/Q19858748', '73C7215')
# ('http://www.wikidata.org/entity/Q19858752', '73D26')
# ('http://www.wikidata.org/entity/Q19858761', '73D26')
# ('http://www.wikidata.org/entity/Q19858762', '73C721')
# ('http://www.wikidata.org/entity/Q19858777', '73D3321')
# ('http://www.wikidata.org/entity/Q19858803', '73D6251')
# ('http://www.wikidata.org/entity/Q19858810', '73D69')
# ('http://www.wikidata.org/entity/Q19858835', '73E422')
# ('http://www.wikidata.org/entity/Q19859141', '73G411')
# ('http://www.wikidata.org/entity/Q19911426', '11HH(BARBARA)68')
# ('http://www.wikidata.org/entity/Q19911782', '11I62(NOAH)')
# ('http://www.wikidata.org/entity/Q19912549', '73C8613')
# ('http://www.wikidata.org/entity/Q19925707', '71T74')
# ('http://www.wikidata.org/entity/Q19926035', '11F4231')
# ('http://www.wikidata.org/entity/Q19926127', '73G411')
# ('http://www.wikidata.org/entity/Q20167131', '11V4')
# ('http://www.wikidata.org/entity/Q20171681', '73G411')
# ('http://www.wikidata.org/entity/Q20173011', '11H(MATTHEW)9')
# ('http://www.wikidata.org/entity/Q20173083', '11H(PAUL)9')
# ('http://www.wikidata.org/entity/Q20173439', '11F234')
# ('http://www.wikidata.org/entity/Q20173439', '73A4(+3)')
# ('http://www.wikidata.org/entity/Q20173760', '73E422')
# ('http://www.wikidata.org/entity/Q20174133', '73B57(+5)')
# ('http://www.wikidata.org/entity/Q20174886', '73C23')
# ('http://www.wikidata.org/entity/Q20175763', '11HH(MARY SALOME)0')
# ('http://www.wikidata.org/entity/Q20176388', '73B82(+3)')
# ('http://www.wikidata.org/entity/Q20185488', '73G411')
# ('http://www.wikidata.org/entity/Q20200967', '11H(MARTIAL)0')
# ('http://www.wikidata.org/entity/Q20200967', '11H(SEBASTIAN)0')
# ('http://www.wikidata.org/entity/Q20392018', '73D341')
# ('http://www.wikidata.org/entity/Q20490981', '73C8613')
# ('http://www.wikidata.org/entity/Q20490984', '73C8321')
# ('http://www.wikidata.org/entity/Q20501084', '73C23')
# ('http://www.wikidata.org/entity/Q20555288', '73F3566')
# ('http://www.wikidata.org/entity/Q20809871', '71T74')
# ('http://www.wikidata.org/entity/Q20891271', '11HH(MARY MAGDALENE)361')
# ('http://www.wikidata.org/entity/Q21422900', '73D341')
# ('http://www.wikidata.org/entity/Q21495736', '71T74')
# ('http://www.wikidata.org/entity/Q21614663', '73C8613')
# ('http://www.wikidata.org/entity/Q22022855', '11H(THOMAS)9')
# ('http://www.wikidata.org/entity/Q23015617', '73C8613')
# ('http://www.wikidata.org/entity/Q23758213', '73C8613')
# ('http://www.wikidata.org/entity/Q24035115', '73E422')
# ('http://www.wikidata.org/entity/Q25692200', '73B57(+5)')
# ('http://www.wikidata.org/entity/Q26999884', '11V4')
# ('http://www.wikidata.org/entity/Q27950229', '73C8613')
# ('http://www.wikidata.org/entity/Q27974770', '73C8613')
# ('http://www.wikidata.org/entity/Q28001558', '73C222')
# ('http://www.wikidata.org/entity/Q28008721', '73F3566')
# ('http://www.wikidata.org/entity/Q28014060', '73C7215')
# ('http://www.wikidata.org/entity/Q29647909', '73C8613')
# ('http://www.wikidata.org/entity/Q43580626', '73C7215')
# ('http://www.wikidata.org/entity/Q46998248', '71L18321')
# ('http://www.wikidata.org/entity/Q50289501', '73E422')
# ('http://www.wikidata.org/entity/Q152851', '25H2')
# ('http://www.wikidata.org/entity/Q153552', '25H2')
# ('http://www.wikidata.org/entity/Q172558', '25F36(SWAN)')
# ('http://www.wikidata.org/entity/Q172558', '25H2')
# ('http://www.wikidata.org/entity/Q311243', '26B1')
# ('http://www.wikidata.org/entity/Q328523', '26B1')
# ('http://www.wikidata.org/entity/Q398126', '25H2')
# ('http://www.wikidata.org/entity/Q3463874', '25G3(+21)')
# ('http://www.wikidata.org/entity/Q17335392', '25I')
# ('http://www.wikidata.org/entity/Q18602603', '26B1')
# ('http://www.wikidata.org/entity/Q21744178', '25H2')
# ('http://www.wikidata.org/entity/Q27998218', '26B1')
# ('http://www.wikidata.org/entity/Q27998557', '26B1')
# ('http://www.wikidata.org/entity/Q28003223', '26B1')
# ('http://www.wikidata.org/entity/Q28006785', '26B1')
# ('http://www.wikidata.org/entity/Q28009494', '26B1')
# ('http://www.wikidata.org/entity/Q28014131', '26B1')
# ('http://www.wikidata.org/entity/Q92385425', '31A235(+1)')
# ('http://www.wikidata.org/entity/Q28002713', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28002810', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28002836', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28002933', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28003033', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28003296', '46E3')
# ('http://www.wikidata.org/entity/Q28003309', '46E3')
# ('http://www.wikidata.org/entity/Q28003354', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28003421', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28003901', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28003943', '46E3')
# ('http://www.wikidata.org/entity/Q28003952', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28003973', '46E3')
# ('http://www.wikidata.org/entity/Q28003996', '46E3')
# ('http://www.wikidata.org/entity/Q28003999', '46E3')
# ('http://www.wikidata.org/entity/Q28004129', '47D41(+99)')
# ('http://www.wikidata.org/entity/Q28004660', '46E3')
# ('http://www.wikidata.org/entity/Q28004692', '47D41(+99)')
# ('http://www.wikidata.org/entity/Q28004696', '46E3')
# ('http://www.wikidata.org/entity/Q28005137', '46E3')
# ('http://www.wikidata.org/entity/Q28005141', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28005181', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28005574', '46E3')
# ('http://www.wikidata.org/entity/Q28005637', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28005642', '46E3')
# ('http://www.wikidata.org/entity/Q28005769', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28005884', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28005891', '46E3')
# ('http://www.wikidata.org/entity/Q28005914', '46E3')
# ('http://www.wikidata.org/entity/Q28006064', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28006090', '46E3')
# ('http://www.wikidata.org/entity/Q28006110', '46E3')
# ('http://www.wikidata.org/entity/Q28006112', '46E3')
# ('http://www.wikidata.org/entity/Q28006113', '46E3')
# ('http://www.wikidata.org/entity/Q28006128', '46E3')
# ('http://www.wikidata.org/entity/Q28006143', '46E3')
# ('http://www.wikidata.org/entity/Q28006170', '46E3')
# ('http://www.wikidata.org/entity/Q28006321', '47D41(+99)')
# ('http://www.wikidata.org/entity/Q28006324', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28006326', '46E3')
# ('http://www.wikidata.org/entity/Q28006489', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28006671', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28006846', '46E3')
# ('http://www.wikidata.org/entity/Q28006905', '46E3')
# ('http://www.wikidata.org/entity/Q28006958', '46E3')
# ('http://www.wikidata.org/entity/Q28007266', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28007521', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28007522', '46E3')
# ('http://www.wikidata.org/entity/Q28007647', '46E3')
# ('http://www.wikidata.org/entity/Q28007678', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28007682', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28007732', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28007766', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28007853', '46E3')
# ('http://www.wikidata.org/entity/Q28007875', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28008178', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28008192', '46E3')
# ('http://www.wikidata.org/entity/Q28008201', '46E3')
# ('http://www.wikidata.org/entity/Q28008222', '46E3')
# ('http://www.wikidata.org/entity/Q28008644', '46E3')
# ('http://www.wikidata.org/entity/Q28008719', '46E3')
# ('http://www.wikidata.org/entity/Q28008731', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28008738', '47C731(+5)')
# ('http://www.wikidata.org/entity/Q28008860', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28008981', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28009425', '46E3')
# ('http://www.wikidata.org/entity/Q28009441', '47G541(+442)')
# ('http://www.wikidata.org/entity/Q28009452', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28009502', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28009591', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28009605', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28009610', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q28015682', '46E3')
# ('http://www.wikidata.org/entity/Q28015957', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q58343120', '46E3')
# ('http://www.wikidata.org/entity/Q58371798', '46C29(+63)')
# ('http://www.wikidata.org/entity/Q58426728', '46E3')
# ('http://www.wikidata.org/entity/Q58428895', '46E3')
# ('http://www.wikidata.org/entity/Q318947', '73E343')
# ('http://www.wikidata.org/entity/Q676955', '73E343')
# ('http://www.wikidata.org/entity/Q881025', '73B13(+5)')
# ('http://www.wikidata.org/entity/Q1192570', '31A41111')
# ('http://www.wikidata.org/entity/Q1241088', '73E343')
# ('http://www.wikidata.org/entity/Q1433194', '73B13(+5)')
# ('http://www.wikidata.org/entity/Q1752990', '98B(SOCRATES)68')
# ('http://www.wikidata.org/entity/Q1905679', '11F422')
# ('http://www.wikidata.org/entity/Q1905679', '46A124')
# ('http://www.wikidata.org/entity/Q2097931', '73E343')
# ('http://www.wikidata.org/entity/Q2113773', '71A611')
# ('http://www.wikidata.org/entity/Q2276130', '11HH(AGNES)')
# ('http://www.wikidata.org/entity/Q2390224', '11HH(WILGEFORTIS)')
# ('http://www.wikidata.org/entity/Q2410044', '42AA51')
# ('http://www.wikidata.org/entity/Q2438357', '31FF23')
# ('http://www.wikidata.org/entity/Q2452374', '71I32')
# ('http://www.wikidata.org/entity/Q2583260', '49D452')
# ('http://www.wikidata.org/entity/Q2835885', '11HH(ELISABETH)')
# ('http://www.wikidata.org/entity/Q2835885', '73A14(+0)')
# ('http://www.wikidata.org/entity/Q3027582', '11C23')
# ('http://www.wikidata.org/entity/Q3027583', '11C23')
# ('http://www.wikidata.org/entity/Q3090610', '25I145')
# ('http://www.wikidata.org/entity/Q17324382', '46B111')
# ('http://www.wikidata.org/entity/Q17324785', '33A35')
# ('http://www.wikidata.org/entity/Q17324785', '46C22')
# ('http://www.wikidata.org/entity/Q17324873', '26C32')
# ('http://www.wikidata.org/entity/Q17325112', '25H1314')
# ('http://www.wikidata.org/entity/Q17325112', '26C32')
# ('http://www.wikidata.org/entity/Q17326743', '42F341')
# ('http://www.wikidata.org/entity/Q17326910', '44B152(+0)')
# ('http://www.wikidata.org/entity/Q17327854', '48C514')
# ('http://www.wikidata.org/entity/Q17328328', '33C213')
# ('http://www.wikidata.org/entity/Q17328469', '42F53')
# ('http://www.wikidata.org/entity/Q17330773', '49E121')
# ('http://www.wikidata.org/entity/Q17331037', '46C22')
# ('http://www.wikidata.org/entity/Q17331950', '92L18(VINE)')
# ('http://www.wikidata.org/entity/Q17331955', '41B211')
# ('http://www.wikidata.org/entity/Q17334098', '46B111')
# ('http://www.wikidata.org/entity/Q17334114', '48CC742')
# ('http://www.wikidata.org/entity/Q17334380', '73C8612')
# ('http://www.wikidata.org/entity/Q17334431', '71C3232')
# ('http://www.wikidata.org/entity/Q17334887', '49E2513')
# ('http://www.wikidata.org/entity/Q17335284', '92C4211')
# ('http://www.wikidata.org/entity/Q17335624', '45C22')
# ('http://www.wikidata.org/entity/Q17336097', '42E272')
# ('http://www.wikidata.org/entity/Q17336148', '41D262')
# ('http://www.wikidata.org/entity/Q17337876', '43C911')
# ('http://www.wikidata.org/entity/Q17338230', '48A9872')
# ('http://www.wikidata.org/entity/Q17338245', '48A9872')
# ('http://www.wikidata.org/entity/Q17338253', '48A9872')
# ('http://www.wikidata.org/entity/Q17338261', '48A9872')
# ('http://www.wikidata.org/entity/Q17338390', '48C513(+111)')
# ('http://www.wikidata.org/entity/Q17338765', '48C514')
# ('http://www.wikidata.org/entity/Q17338827', '48C514')
# ('http://www.wikidata.org/entity/Q17340884', '41C52')
# ('http://www.wikidata.org/entity/Q17340884', '47I422')
# ('http://www.wikidata.org/entity/Q17341008', '92C4211')
# ('http://www.wikidata.org/entity/Q17341172', '26C32')
# ('http://www.wikidata.org/entity/Q17341246', '41B211')
# ('http://www.wikidata.org/entity/Q17341265', '25H156')
# ('http://www.wikidata.org/entity/Q17341443', '48C5212')
# ('http://www.wikidata.org/entity/Q17341536', '92B12181')
# ('http://www.wikidata.org/entity/Q17341554', '41D262')
# ('http://www.wikidata.org/entity/Q17341997', '48C514')
# ('http://www.wikidata.org/entity/Q17342053', '46C181')
# ('http://www.wikidata.org/entity/Q17342127', '45C22')
# ('http://www.wikidata.org/entity/Q17342545', '45C14(HALBERD)')
# ('http://www.wikidata.org/entity/Q17342894', '41A222')
# ('http://www.wikidata.org/entity/Q17342894', '48B13')
# ('http://www.wikidata.org/entity/Q17342894', '48C52')
# ('http://www.wikidata.org/entity/Q17342921', '34B12(+1)')
# ('http://www.wikidata.org/entity/Q18572953', '73B56')
# ('http://www.wikidata.org/entity/Q18686590', '73C7223')
# ('http://www.wikidata.org/entity/Q19911478', '73E425')
# ('http://www.wikidata.org/entity/Q19928812', '73C7223')
# ('http://www.wikidata.org/entity/Q21711530', '25G41(NARCISSUS)')
# ('http://www.wikidata.org/entity/Q27982145', '25G41(TULIP)')
# ('http://www.wikidata.org/entity/Q28001986', '48C5212')
# ('http://www.wikidata.org/entity/Q28003990', '25H156')
# ('http://www.wikidata.org/entity/Q28005610', '26C32')
# ('http://www.wikidata.org/entity/Q28005898', '41A222')
# ('http://www.wikidata.org/entity/Q28006041', '26C32')
# ('http://www.wikidata.org/entity/Q28006043', '26C32')
# ('http://www.wikidata.org/entity/Q28006070', '25G41(TULIP)')
# ('http://www.wikidata.org/entity/Q28007972', '25H156')
# ('http://www.wikidata.org/entity/Q58425694', '73B56')
# ('http://www.wikidata.org/entity/Q23898', '11F421')
# ('http://www.wikidata.org/entity/Q474409', '11F421')
# ('http://www.wikidata.org/entity/Q577248', '11H(MATTHEW)12')
# ('http://www.wikidata.org/entity/Q2337873', '11H(MATTHEW)12')
# ('http://www.wikidata.org/entity/Q2401792', '11T')
# ('http://www.wikidata.org/entity/Q2401792', '71A3421')
# ('http://www.wikidata.org/entity/Q2401792', '71A62')
# ('http://www.wikidata.org/entity/Q3202430', '73E42')
# ('http://www.wikidata.org/entity/Q3399498', '11P3112')
# ('http://www.wikidata.org/entity/Q3605528', '11H(STEPHEN)')
# ('http://www.wikidata.org/entity/Q3620832', '71B323')
# ('http://www.wikidata.org/entity/Q3624813', '73E42')
# ('http://www.wikidata.org/entity/Q3687181', '11H(PETER)4')
# ('http://www.wikidata.org/entity/Q3696835', '71A3421')
# ('http://www.wikidata.org/entity/Q3697598', '73C72233')
# ('http://www.wikidata.org/entity/Q3697607', '73D3231')
# ('http://www.wikidata.org/entity/Q3697627', '73C72233')
# ('http://www.wikidata.org/entity/Q3697632', '73D732')
# ('http://www.wikidata.org/entity/Q3710271', '73F3561')
# ('http://www.wikidata.org/entity/Q3735190', '11H(MATTHEW)12')
# ('http://www.wikidata.org/entity/Q3842383', '73B82(+0)')
# ('http://www.wikidata.org/entity/Q3869770', '11I62(NAHSHON)')
# ('http://www.wikidata.org/entity/Q3907503', '11F421')
# ('http://www.wikidata.org/entity/Q3907503', '11H(LAURENCE)')
# ('http://www.wikidata.org/entity/Q3907503', '11H(SYLVESTER)')
# ('http://www.wikidata.org/entity/Q3910089', '11H(PETER)4')
# ('http://www.wikidata.org/entity/Q3932055', '92L192')
# ('http://www.wikidata.org/entity/Q3936375', '73B65(+0)')
# ('http://www.wikidata.org/entity/Q3947666', '11H(MATTHEW)12')
# ('http://www.wikidata.org/entity/Q3947764', '11H(PAUL)7')
# ('http://www.wikidata.org/entity/Q3947823', '73F21541')
# ('http://www.wikidata.org/entity/Q3949373', '11H(STEPHEN)')
# ('http://www.wikidata.org/entity/Q3949514', '11H(STEPHEN)')
# ('http://www.wikidata.org/entity/Q3998949', '71U')
# ('http://www.wikidata.org/entity/Q4008998', '71Q2131')
# ('http://www.wikidata.org/entity/Q4010596', '73D413')
# ('http://www.wikidata.org/entity/Q167082', '41C312')
# ('http://www.wikidata.org/entity/Q175628', '46A173')
# ('http://www.wikidata.org/entity/Q204243', '11H(ROCH)7')
# ('http://www.wikidata.org/entity/Q500951', '23D44')
# ('http://www.wikidata.org/entity/Q1851182', '11P3113')
# ('http://www.wikidata.org/entity/Q2480921', '11P3113')
# ('http://www.wikidata.org/entity/Q2551113', '11H(ANTONY ABBOT)352')
# ('http://www.wikidata.org/entity/Q3999113', '11H(DOMINIC)')
# ('http://www.wikidata.org/entity/Q9396820', '73F2452')
# ('http://www.wikidata.org/entity/Q17319804', '25B')
# ('http://www.wikidata.org/entity/Q17320910', '45F9')
# ('http://www.wikidata.org/entity/Q17323007', '25F711(CATERPILLAR)')
# ('http://www.wikidata.org/entity/Q17323056', '25F711(CATERPILLAR)')
# ('http://www.wikidata.org/entity/Q17323780', '23D44')
# ('http://www.wikidata.org/entity/Q17324251', '47B2')
# ('http://www.wikidata.org/entity/Q17324469', '11H(ANTONY OF PADUA)')
# ('http://www.wikidata.org/entity/Q17324783', '23F42')
# ('http://www.wikidata.org/entity/Q17326882', '42Z113')
# ('http://www.wikidata.org/entity/Q17327167', '45C16')
# ('http://www.wikidata.org/entity/Q17330578', '45C16')
# ('http://www.wikidata.org/entity/Q17335810', '11H(IGNATIUS OF ANTIOCH)')
# ('http://www.wikidata.org/entity/Q17335867', '11H(COSMAS & DAMIAN)')
# ('http://www.wikidata.org/entity/Q17338807', '11H(COSMAS & DAMIAN)')
# ('http://www.wikidata.org/entity/Q17339902', '45K13')
# ('http://www.wikidata.org/entity/Q17341246', '23D41')
# ('http://www.wikidata.org/entity/Q17341412', '46C2822')
# ('http://www.wikidata.org/entity/Q17342545', '45C16')
# ('http://www.wikidata.org/entity/Q18508790', '11HH(VERONICA)9')
# ('http://www.wikidata.org/entity/Q19858349', '11I72(JUDAS ISCARIOT)')
# ('http://www.wikidata.org/entity/Q19858379', '73D55')
# ('http://www.wikidata.org/entity/Q19858799', '73D55')
# ('http://www.wikidata.org/entity/Q19911759', '11H(BERNARD)')
# ('http://www.wikidata.org/entity/Q21600959', '44G522')
# ('http://www.wikidata.org/entity/Q21711974', '11H(ANTONY ABBOT)352')
# ('http://www.wikidata.org/entity/Q22250341', '73D55')
# ('http://www.wikidata.org/entity/Q22809373', '73D55')
# ('http://www.wikidata.org/entity/Q27481413', '11H(COSMAS & DAMIAN)')
# ('http://www.wikidata.org/entity/Q27998404', '41A36')
# ('http://www.wikidata.org/entity/Q27998989', '23D42')
# ('http://www.wikidata.org/entity/Q28001516', '41C743')
# ('http://www.wikidata.org/entity/Q28001900', '25H161')
# ('http://www.wikidata.org/entity/Q28002039', '41A36')
# ('http://www.wikidata.org/entity/Q28002707', '22C2')
# ('http://www.wikidata.org/entity/Q28005653', '41A36')
# ('http://www.wikidata.org/entity/Q28005794', '34B41')
# ('http://www.wikidata.org/entity/Q28005997', '41A36')
# ('http://www.wikidata.org/entity/Q28006004', '41A36')
# ('http://www.wikidata.org/entity/Q28006106', '25H161')
# ('http://www.wikidata.org/entity/Q28007062', '45C16')
# ('http://www.wikidata.org/entity/Q28007514', '25H161')
# ('http://www.wikidata.org/entity/Q28008368', '23U21')
# ('http://www.wikidata.org/entity/Q28008635', '41A413')
# ('http://www.wikidata.org/entity/Q28008726', '22C2')
# ('http://www.wikidata.org/entity/Q28008866', '22C2')
# ('http://www.wikidata.org/entity/Q28009157', '41A15')
# ('http://www.wikidata.org/entity/Q28009185', '41A36')
# ('http://www.wikidata.org/entity/Q28009233', '22C9')
# ('http://www.wikidata.org/entity/Q28012220', '49D11')
# ('http://www.wikidata.org/entity/Q28015898', '25F43')
# ('http://www.wikidata.org/entity/Q28890626', '11H(ANTONY ABBOT)352')
# ('http://www.wikidata.org/entity/Q58413317', '41C743')
# ('http://www.wikidata.org/entity/Q61743320', '11H(ANTONY ABBOT)352')
# ('http://www.wikidata.org/entity/Q73122306', '11H(BONAVENTURA)')
# ('http://www.wikidata.org/entity/Q92385982', '47B2')
# ('http://www.wikidata.org/entity/Q92392863', '23F42')
# ('http://www.wikidata.org/entity/Q92393544', '47B2')
# ('http://www.wikidata.org/entity/Q92395323', '61B1(+1)')
# ('http://www.wikidata.org/entity/Q92395960', '49D34')
# ('http://www.wikidata.org/entity/Q92397404', '49D34')
# ('http://www.wikidata.org/entity/Q92405127', '22C2')
# ('http://www.wikidata.org/entity/Q92412695', '43C4142')
# ('http://www.wikidata.org/entity/Q101552405', '41A311')
# ('http://www.wikidata.org/entity/Q101552406', '41A311')
# ('http://www.wikidata.org/entity/Q108442868', '73F2452')
# ('http://www.wikidata.org/entity/Q111746089', '25F43')
# ('http://www.wikidata.org/entity/Q3220282', '73C121(+3)')
# ('http://www.wikidata.org/entity/Q17582367', '71K2123')
# ('http://www.wikidata.org/entity/Q18687787', '73C465')
# ('http://www.wikidata.org/entity/Q19858229', '73B67')
# ('http://www.wikidata.org/entity/Q19858235', '73C111')
# ('http://www.wikidata.org/entity/Q19858339', '73C94')
# ('http://www.wikidata.org/entity/Q19858403', '73D7742')
# ('http://www.wikidata.org/entity/Q19858409', '73E33')
# ('http://www.wikidata.org/entity/Q19858416', '73E7')
# ('http://www.wikidata.org/entity/Q19858705', '73C8172')
# ('http://www.wikidata.org/entity/Q19858708', '73C465')
# ('http://www.wikidata.org/entity/Q19858717', '73C72441')
# ('http://www.wikidata.org/entity/Q19858726', '73C7243')
# ('http://www.wikidata.org/entity/Q19858770', '73D316')
# ('http://www.wikidata.org/entity/Q19858781', '73D316')
# ('http://www.wikidata.org/entity/Q19911898', '11H(MATTHIAS)9')
# ('http://www.wikidata.org/entity/Q19912389', '11Q755')
# ('http://www.wikidata.org/entity/Q19912695', '73C121(+3)')
# ('http://www.wikidata.org/entity/Q19926011', '11H(FRANCIS)9')
# ('http://www.wikidata.org/entity/Q19928018', '73A16')
# ('http://www.wikidata.org/entity/Q19928018', '73A19')
# ('http://www.wikidata.org/entity/Q20017508', '11HH(MARY MAGDALENE)36(+3)')
# ('http://www.wikidata.org/entity/Q20176655', '73C4223')
# ('http://www.wikidata.org/entity/Q20181430', '71H2122')
# ('http://www.wikidata.org/entity/Q20183541', '71H2122')
# ('http://www.wikidata.org/entity/Q92385442', '25H2')
# ('http://www.wikidata.org/entity/Q92385447', '25I')
# ('http://www.wikidata.org/entity/Q92385486', '25H2')
# ('http://www.wikidata.org/entity/Q92385513', '25H1381')
# ('http://www.wikidata.org/entity/Q92385557', '25I')
# ('http://www.wikidata.org/entity/Q92385592', '25I')
# ('http://www.wikidata.org/entity/Q92385995', '25H2')
# ('http://www.wikidata.org/entity/Q92386583', '25I7')
# ('http://www.wikidata.org/entity/Q92386586', '25H2')
# ('http://www.wikidata.org/entity/Q92387390', '25I14')
# ('http://www.wikidata.org/entity/Q92387416', '25I14')
# ('http://www.wikidata.org/entity/Q92388501', '25H2')
# ('http://www.wikidata.org/entity/Q92388537', '26B1')
# ('http://www.wikidata.org/entity/Q92388592', '25I')
# ('http://www.wikidata.org/entity/Q92389149', '25I')
# ('http://www.wikidata.org/entity/Q92389839', '25H2')
# ('http://www.wikidata.org/entity/Q92389925', '25I')
# ('http://www.wikidata.org/entity/Q92391068', '26B1')
# ('http://www.wikidata.org/entity/Q92391268', '25H2')
# ('http://www.wikidata.org/entity/Q92391268', '25I')
# ('http://www.wikidata.org/entity/Q92392863', '25H2')
# ('http://www.wikidata.org/entity/Q92394266', '25H2')
# ('http://www.wikidata.org/entity/Q92395331', '25I14')
# ('http://www.wikidata.org/entity/Q92396088', '25I')
# ('http://www.wikidata.org/entity/Q92396794', '25H2')
# ('http://www.wikidata.org/entity/Q92396794', '25HH155')
# ('http://www.wikidata.org/entity/Q92397368', '25H2')
# ('http://www.wikidata.org/entity/Q92400658', '25I')
# ('http://www.wikidata.org/entity/Q92400682', '25I')
# ('http://www.wikidata.org/entity/Q92401230', '25H2')
# ('http://www.wikidata.org/entity/Q92401230', '25I')
# ('http://www.wikidata.org/entity/Q92405148', '25I')
# ('http://www.wikidata.org/entity/Q92413871', '25H2')
# ('http://www.wikidata.org/entity/Q92413964', '24A11')
# ('http://www.wikidata.org/entity/Q111754686', '25I')
# ('http://www.wikidata.org/entity/Q200479', '58AA1')
# ('http://www.wikidata.org/entity/Q275349', '92C4')
# ('http://www.wikidata.org/entity/Q1635039', '71T54')
# ('http://www.wikidata.org/entity/Q3235844', '71T54')
# ('http://www.wikidata.org/entity/Q3944654', '73F223153')
# ('http://www.wikidata.org/entity/Q5996597', '11S1')
# ('http://www.wikidata.org/entity/Q17275788', '59C2')
# ('http://www.wikidata.org/entity/Q17319908', '47I214')
# ('http://www.wikidata.org/entity/Q17319933', '92D1')
# ('http://www.wikidata.org/entity/Q17320048', '48C51151')
# ('http://www.wikidata.org/entity/Q17320048', '48C515')
# ('http://www.wikidata.org/entity/Q17320959', '92D1')
# ('http://www.wikidata.org/entity/Q17320961', '48C5211')
# ('http://www.wikidata.org/entity/Q17320961', '92C4')
# ('http://www.wikidata.org/entity/Q17321232', '61B2(+52)')
# ('http://www.wikidata.org/entity/Q17322114', '61BB2(+53)')
# ('http://www.wikidata.org/entity/Q17322240', '61BB2(+53)')
# ('http://www.wikidata.org/entity/Q17322369', '61BB2(+53)')
# ('http://www.wikidata.org/entity/Q17322735', '71I531')
# ('http://www.wikidata.org/entity/Q17322955', '71I531')
# ('http://www.wikidata.org/entity/Q17323483', '71E1124')
# ('http://www.wikidata.org/entity/Q17323507', '61BB2(+55)')
# ('http://www.wikidata.org/entity/Q17323858', '71C11443')
# ('http://www.wikidata.org/entity/Q17323858', '71C1262')
# ('http://www.wikidata.org/entity/Q17323915', '61BB2(+53)')
# ('http://www.wikidata.org/entity/Q17323979', '94C1131')
# ('http://www.wikidata.org/entity/Q17324297', '73C431')
# ('http://www.wikidata.org/entity/Q17324359', '71I423')
# ('http://www.wikidata.org/entity/Q17324359', '71I4321')
# ('http://www.wikidata.org/entity/Q17325132', '48C51122')
# ('http://www.wikidata.org/entity/Q17325132', '48C5114')
# ('http://www.wikidata.org/entity/Q17326954', '49L6')
# ('http://www.wikidata.org/entity/Q17327696', '71I531')
# ('http://www.wikidata.org/entity/Q17327851', '61B2(+55)')
# ('http://www.wikidata.org/entity/Q17329983', '73B5')
# ('http://www.wikidata.org/entity/Q17330778', '98B(HERACLITUS)51')
# ('http://www.wikidata.org/entity/Q17331658', '47I214')
# ('http://www.wikidata.org/entity/Q17334111', '94C1131')
# ('http://www.wikidata.org/entity/Q17334134', '49M12')
# ('http://www.wikidata.org/entity/Q17334394', '92C4')
# ('http://www.wikidata.org/entity/Q17334815', '61B2(+55)')
# ('http://www.wikidata.org/entity/Q17334821', '48CC7341')
# ('http://www.wikidata.org/entity/Q17334940', '61B2(+55)')
# ('http://www.wikidata.org/entity/Q17335284', '92D1')
# ('http://www.wikidata.org/entity/Q17335673', '47H312')
# ('http://www.wikidata.org/entity/Q17335807', '98B(ALEXANDER THE GREAT)411(+0)')
# ('http://www.wikidata.org/entity/Q17335847', '73A53(+0)')
# ('http://www.wikidata.org/entity/Q17337965', '48A8')
# ('http://www.wikidata.org/entity/Q17337984', '47K11')
# ('http://www.wikidata.org/entity/Q17338325', '48C512')
# ('http://www.wikidata.org/entity/Q17338673', '92C321')
# ('http://www.wikidata.org/entity/Q17338673', '92D1')
# ('http://www.wikidata.org/entity/Q17339840', '61BB2(+51)')
# ('http://www.wikidata.org/entity/Q17340541', '96C(AENEAS)692')
# ('http://www.wikidata.org/entity/Q17341200', '71C1241')
# ('http://www.wikidata.org/entity/Q17341200', '71C12521')
# ('http://www.wikidata.org/entity/Q17341231', '71T54')
# ('http://www.wikidata.org/entity/Q17341344', '61B2(+55)')
# ('http://www.wikidata.org/entity/Q17341551', '92B5722')
# ('http://www.wikidata.org/entity/Q17341554', '92B5722')
# ('http://www.wikidata.org/entity/Q17341557', '92B5722')
# ('http://www.wikidata.org/entity/Q17342315', '47I214')
# ('http://www.wikidata.org/entity/Q17343135', '73B5')
# ('http://www.wikidata.org/entity/Q17343182', '49L73')
# ('http://www.wikidata.org/entity/Q17347270', '48A81121')
# ('http://www.wikidata.org/entity/Q18688335', '11HH(HELENA)')
# ('http://www.wikidata.org/entity/Q18688983', '71E118')
# ('http://www.wikidata.org/entity/Q18689513', '73B6')
# ('http://www.wikidata.org/entity/Q18748408', '73D322')
# ('http://www.wikidata.org/entity/Q18748474', '73C311')
# ('http://www.wikidata.org/entity/Q18748548', '71C31211')
# ('http://www.wikidata.org/entity/Q18890659', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q19858279', '73C311')
# ('http://www.wikidata.org/entity/Q19858357', '73D322')
# ('http://www.wikidata.org/entity/Q19858371', '73D411')
# ('http://www.wikidata.org/entity/Q20202542', '73D411')
# ('http://www.wikidata.org/entity/Q20266888', '73D411')
# ('http://www.wikidata.org/entity/Q20267608', '73D411')
# ('http://www.wikidata.org/entity/Q21711484', '73D411')
# ('http://www.wikidata.org/entity/Q21712166', '73C311')
# ('http://www.wikidata.org/entity/Q21730878', '71C31211')
# ('http://www.wikidata.org/entity/Q22250340', '73D411')
# ('http://www.wikidata.org/entity/Q27482084', '11H(MARTIN)')
# ('http://www.wikidata.org/entity/Q27998423', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q27998585', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q27998718', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q27999063', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q27999255', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28000376', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28000622', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28001130', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28001210', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28001243', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28001246', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28001247', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28001285', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28001661', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28001667', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28001698', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28001705', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28001717', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28001719', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28001721', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28001731', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28001734', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28001735', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28001745', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28001775', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28001960', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28001992', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28002014', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28002065', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28002099', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28002258', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28002306', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28002461', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28002678', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28002721', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28002888', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28002896', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28003035', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q28003203', '48C513(+27)')
# ('http://www.wikidata.org/entity/Q29871370', '73C11')
# ('http://www.wikidata.org/entity/Q30057201', '73C11')
# ('http://www.wikidata.org/entity/Q31776302', '73C421')
# ('http://www.wikidata.org/entity/Q33104607', '71C31211')
# ('http://www.wikidata.org/entity/Q45182340', '73C11')
# ('http://www.wikidata.org/entity/Q23946', '73A624')
# ('http://www.wikidata.org/entity/Q571122', '11H(GEORGE)')
# ('http://www.wikidata.org/entity/Q1905679', '11H(GEORGE)')
# ('http://www.wikidata.org/entity/Q2453980', '73A18')
# ('http://www.wikidata.org/entity/Q2480921', '11H(GEORGE)')
# ('http://www.wikidata.org/entity/Q2608103', '11H(JOSEPH)')
# ('http://www.wikidata.org/entity/Q3463874', '73A18')
# ('http://www.wikidata.org/entity/Q3463877', '73A18')
# ('http://www.wikidata.org/entity/Q3605033', '11I62(ADAM)')
# ('http://www.wikidata.org/entity/Q4556646', '73A18')
# ('http://www.wikidata.org/entity/Q7401482', '73A18')
# ('http://www.wikidata.org/entity/Q9396800', '11H(FRANCIS)37')
# ('http://www.wikidata.org/entity/Q9396822', '73A18')
# ('http://www.wikidata.org/entity/Q11747765', '73A18')
# ('http://www.wikidata.org/entity/Q11800605', '73D242')
# ('http://www.wikidata.org/entity/Q15117526', '11H(GEORGE)')
# ('http://www.wikidata.org/entity/Q16543207', '11H(FRANCIS)37')
# ('http://www.wikidata.org/entity/Q16621985', '11H(JAMES THE LESS)')
# ('http://www.wikidata.org/entity/Q17338780', '11H(GEORGE)')
# ('http://www.wikidata.org/entity/Q18683067', '11H(JOSEPH)')
# ('http://www.wikidata.org/entity/Q18929741', '73A18')
# ('http://www.wikidata.org/entity/Q19788073', '11H(JOSEPH)')
# ('http://www.wikidata.org/entity/Q19858215', '11H(JOSEPH)')
# ('http://www.wikidata.org/entity/Q19858350', '11H(JAMES THE LESS)')
# ('http://www.wikidata.org/entity/Q19858758', '73D242')
# ('http://www.wikidata.org/entity/Q20174367', '73A18')
# ('http://www.wikidata.org/entity/Q20266249', '73A18')
# ('http://www.wikidata.org/entity/Q20266372', '73A18')
# ('http://www.wikidata.org/entity/Q21480444', '11H(JOSEPH)')
# ('http://www.wikidata.org/entity/Q21815237', '11H(JOSEPH)')
# ('http://www.wikidata.org/entity/Q22945980', '73A18')
# ('http://www.wikidata.org/entity/Q25444052', '73A624')
# ('http://www.wikidata.org/entity/Q26133903', '73D242')
# ('http://www.wikidata.org/entity/Q27058597', '11H(GEORGE)')
# ('http://www.wikidata.org/entity/Q27697307', '11I62(ADAM)')
# ('http://www.wikidata.org/entity/Q27697886', '73A624')
# ('http://www.wikidata.org/entity/Q27698890', '73D242')
# ('http://www.wikidata.org/entity/Q27698920', '73A18')
# ('http://www.wikidata.org/entity/Q3090610', '41A14')
# ('http://www.wikidata.org/entity/Q3649315', '71A611')
# ('http://www.wikidata.org/entity/Q3664357', '73E343')
# ('http://www.wikidata.org/entity/Q3664358', '73E343')
# ('http://www.wikidata.org/entity/Q3830575', '11I423')
# ('http://www.wikidata.org/entity/Q3830577', '11I423')
# ('http://www.wikidata.org/entity/Q3873252', '73B13(+5)')
# ('http://www.wikidata.org/entity/Q11091298', '73E343')
# ('http://www.wikidata.org/entity/Q11091772', '73E343')
# ('http://www.wikidata.org/entity/Q11690351', '73E343')
# ('http://www.wikidata.org/entity/Q16025001', '73E343')
# ('http://www.wikidata.org/entity/Q16038665', '73B13(+5)')
# ('http://www.wikidata.org/entity/Q17319689', '25I145')
# ('http://www.wikidata.org/entity/Q17319731', '25I145')
# ('http://www.wikidata.org/entity/Q17319861', '25I145')
# ('http://www.wikidata.org/entity/Q17320056', '25I145')
# ('http://www.wikidata.org/entity/Q17322898', '71A611')
# ('http://www.wikidata.org/entity/Q17324952', '73E343')
# ('http://www.wikidata.org/entity/Q17326869', '44B')
# ('http://www.wikidata.org/entity/Q17328710', '25I145')
# ('http://www.wikidata.org/entity/Q17331256', '25I145')
# ('http://www.wikidata.org/entity/Q17334929', '41A14')
# ('http://www.wikidata.org/entity/Q17335483', '25I145')
# ('http://www.wikidata.org/entity/Q17340804', '25I145')
# ('http://www.wikidata.org/entity/Q17341995', '25I145')
# ('http://www.wikidata.org/entity/Q17344299', '25I145')
# ('http://www.wikidata.org/entity/Q18572449', '71A611')
# ('http://www.wikidata.org/entity/Q18917064', '73E343')
# ('http://www.wikidata.org/entity/Q19318713', '11C23')
# ('http://www.wikidata.org/entity/Q19803784', '73E343')
# ('http://www.wikidata.org/entity/Q19833785', '73E343')
# ('http://www.wikidata.org/entity/Q19858382', '73D6241')
# ('http://www.wikidata.org/entity/Q19859035', '73E343')
# ('http://www.wikidata.org/entity/Q19911559', '73B13(+5)')
# ('http://www.wikidata.org/entity/Q19925857', '73E343')
# ('http://www.wikidata.org/entity/Q19925889', '73E343')
# ('http://www.wikidata.org/entity/Q20183355', '73E343')
# ('http://www.wikidata.org/entity/Q20188304', '73E343')
# ('http://www.wikidata.org/entity/Q20268170', '73E343')
# ('http://www.wikidata.org/entity/Q20355838', '73E343')
# ('http://www.wikidata.org/entity/Q20538879', '71I32')
# ('http://www.wikidata.org/entity/Q20808805', '46A124')
# ('http://www.wikidata.org/entity/Q21401882', '73E343')
# ('http://www.wikidata.org/entity/Q21509458', '11C23')
# ('http://www.wikidata.org/entity/Q21679811', '73E343')
# ('http://www.wikidata.org/entity/Q21684028', '11C23')
# ...
# ('http://www.wikidata.org/entity/Q93201260', '41A711')
# ('http://www.wikidata.org/entity/Q100235804', '92B3721')
# ('http://www.wikidata.org/entity/Q377394', '11P3111')
# ('http://www.wikidata.org/entity/Q474096', '25H22')
# ('http://www.wikidata.org/entity/Q477764', '25F711(BUTTERFLY)')
# ('http://www.wikidata.org/entity/Q2284829', '71C131')
# ('http://www.wikidata.org/entity/Q2448678', '73B63')
# ('http://www.wikidata.org/entity/Q3983802', '11H(ANTONY ABBOT)351')
# ('http://www.wikidata.org/entity/Q6119249', '11H(LUKE)111')
# ('http://www.wikidata.org/entity/Q6643824', '71C131')
# ('http://www.wikidata.org/entity/Q7732151', '73G313')
# ('http://www.wikidata.org/entity/Q7732151', '73G4933')
# ('http://www.wikidata.org/entity/Q9008977', '48C73341')
# ('http://www.wikidata.org/entity/Q9347431', '11H(JAMES THE LESS)9')
# ('http://www.wikidata.org/entity/Q9395953', '11H(ALEXIS)4')
# ('http://www.wikidata.org/entity/Q10303119', '11Q71454')
# ('http://www.wikidata.org/entity/Q10303119', '11Q7312')
# ('http://www.wikidata.org/entity/Q10749451', '71C131')
# ('http://www.wikidata.org/entity/Q11364918', '73F215365')
# ('http://www.wikidata.org/entity/Q11695673', '41D211(+82)')
# ('http://www.wikidata.org/entity/Q11708247', '71L2121')
# ('http://www.wikidata.org/entity/Q11769269', '11HH(MARY OF EGYPT)')
# ('http://www.wikidata.org/entity/Q11830152', '73C7421')
# ('http://www.wikidata.org/entity/Q12089282', '71O933')
# ('http://www.wikidata.org/entity/Q12878468', '71A84')
# ('http://www.wikidata.org/entity/Q13418238', '31A236')
# ('http://www.wikidata.org/entity/Q13418238', '41D211(+82)')
# ('http://www.wikidata.org/entity/Q13571630', '25H22')
# ('http://www.wikidata.org/entity/Q15674230', '73B63')
# ('http://www.wikidata.org/entity/Q15691130', '73B63')
# ('http://www.wikidata.org/entity/Q15874417', '11H(ANTONY ABBOT)351')
# ('http://www.wikidata.org/entity/Q15974364', '73B821(+3)')
# ('http://www.wikidata.org/entity/Q16161113', '73B21(+3)')
# ('http://www.wikidata.org/entity/Q16599633', '71F341')
# ('http://www.wikidata.org/entity/Q16621982', '11H(JAMES THE LESS)9')
# ('http://www.wikidata.org/entity/Q16913580', '41D221(CAP)(+43)')
# ('http://www.wikidata.org/entity/Q16913580', '41D222(COLLAR)(+43)')
# ('http://www.wikidata.org/entity/Q17319772', '41B31')
# ('http://www.wikidata.org/entity/Q17319827', '73B63')
# ('http://www.wikidata.org/entity/Q17319901', '25F711(BUTTERFLY)')
# ('http://www.wikidata.org/entity/Q17320364', '41B31')
# ('http://www.wikidata.org/entity/Q17320929', '11P16')
# ('http://www.wikidata.org/entity/Q17320929', '11P31')
# ('http://www.wikidata.org/entity/Q17320929', '11P3111')
# ('http://www.wikidata.org/entity/Q17320929', '11P4421')
# ('http://www.wikidata.org/entity/Q17320997', '11HH(CECILIA)')
# ('http://www.wikidata.org/entity/Q17323490', '11HH(CECILIA)')
# ('http://www.wikidata.org/entity/Q17323818', '12F61')
# ('http://www.wikidata.org/entity/Q17323843', '25H22')
# ('http://www.wikidata.org/entity/Q17323878', '11D121')
# ('http://www.wikidata.org/entity/Q17323878', '11G191')
# ('http://www.wikidata.org/entity/Q17323878', '11G1925')
# ('http://www.wikidata.org/entity/Q17323879', '11G191')
# ('http://www.wikidata.org/entity/Q17323880', '11G191')
# ('http://www.wikidata.org/entity/Q17323881', '11G191')
# ('http://www.wikidata.org/entity/Q17324244', '25H22')
# ('http://www.wikidata.org/entity/Q17324469', '11H(ANTONY OF PADUA)31')
# ('http://www.wikidata.org/entity/Q17324469', '11Q731114')
# ('http://www.wikidata.org/entity/Q17324927', '11I2(ERYTHRAEAN)')
# ('http://www.wikidata.org/entity/Q17330778', '25A13')
# ('http://www.wikidata.org/entity/Q17334134', '25A13')
# ('http://www.wikidata.org/entity/Q17334158', '11HH(CECILIA)')
# ('http://www.wikidata.org/entity/Q17334377', '41B31')
# ('http://www.wikidata.org/entity/Q17334442', '41D222(COLLAR)(+43)')
# ('http://www.wikidata.org/entity/Q17334813', '11DD324')
# ('http://www.wikidata.org/entity/Q17334813', '11FF4223')
# ('http://www.wikidata.org/entity/Q17334958', '11H(HUBERT)34')
# ('http://www.wikidata.org/entity/Q17335599', '25A13')
# ('http://www.wikidata.org/entity/Q17335989', '41D211(+82)')
# ('http://www.wikidata.org/entity/Q17336037', '11R511')
# ('http://www.wikidata.org/entity/Q17340541', '23D4')
# ('http://www.wikidata.org/entity/Q17341200', '25F23(FOX)')
# ('http://www.wikidata.org/entity/Q17341448', '25H22')
# ('http://www.wikidata.org/entity/Q17341472', '25A13')
# ('http://www.wikidata.org/entity/Q17522291', '71C131')
# ('http://www.wikidata.org/entity/Q17894284', '11R511')
# ('http://www.wikidata.org/entity/Q18572518', '11FF4223')
# ('http://www.wikidata.org/entity/Q18575358', '73B63')
# ('http://www.wikidata.org/entity/Q18608112', '25H22')
# ('http://www.wikidata.org/entity/Q19858231', '73B71')
# ('http://www.wikidata.org/entity/Q19858676', '73C7421')
# ('http://www.wikidata.org/entity/Q19963608', '11H(LUKE)111')
# ('http://www.wikidata.org/entity/Q20172942', '11H(JAMES THE LESS)9')
# ('http://www.wikidata.org/entity/Q20177082', '11F31')
# ('http://www.wikidata.org/entity/Q20274148', '73B21(+3)')
# ('http://www.wikidata.org/entity/Q20440719', '73B63')
# ('http://www.wikidata.org/entity/Q20809369', '11HH(MARY OF EGYPT)')
# ('http://www.wikidata.org/entity/Q21617732', '73B71')
# ('http://www.wikidata.org/entity/Q21715919', '11R511')
# ('http://www.wikidata.org/entity/Q21716811', '73B821(+3)')
# ('http://www.wikidata.org/entity/Q26706614', '11H(HUBERT)34')
# ('http://www.wikidata.org/entity/Q27478118', '11HH(CECILIA)')
# ('http://www.wikidata.org/entity/Q27482084', '71C131')
# ('http://www.wikidata.org/entity/Q27655716', '31A236')
# ('http://www.wikidata.org/entity/Q27978179', '73B821(+3)')
# ('http://www.wikidata.org/entity/Q27982145', '11R511')
# ('http://www.wikidata.org/entity/Q28007609', '11HH(CECILIA)')
# ('http://www.wikidata.org/entity/Q94802', '11H(PAUL)0')
# ('http://www.wikidata.org/entity/Q743787', '73DD643')
# ('http://www.wikidata.org/entity/Q3565300', '73B2')
# ('http://www.wikidata.org/entity/Q3697613', '73E15')
# ('http://www.wikidata.org/entity/Q3697666', '73E15')
# ('http://www.wikidata.org/entity/Q3697667', '73E15')
# ('http://www.wikidata.org/entity/Q3702112', '71P3411')
# ('http://www.wikidata.org/entity/Q3974472', '71B35211')
# ('http://www.wikidata.org/entity/Q5948994', '73B65(+3)')
# ('http://www.wikidata.org/entity/Q8353711', '71P3411')
# ('http://www.wikidata.org/entity/Q9019507', '73E373')
# ('http://www.wikidata.org/entity/Q16913576', '71D134')
# ('http://www.wikidata.org/entity/Q17276051', '12A436')
# ('http://www.wikidata.org/entity/Q17319718', '11H(LUKE)')
# ('http://www.wikidata.org/entity/Q17328521', '73D315')
# ('http://www.wikidata.org/entity/Q17334298', '73DD643')
# ('http://www.wikidata.org/entity/Q17337965', '48A8111')
# ('http://www.wikidata.org/entity/Q17338099', '48A8111')
# ('http://www.wikidata.org/entity/Q17342801', '73D81')
# ('http://www.wikidata.org/entity/Q17627466', '73E373')
# ('http://www.wikidata.org/entity/Q18346971', '73E15')
# ('http://www.wikidata.org/entity/Q18411339', '12A436')
# ('http://www.wikidata.org/entity/Q18573398', '71H3152')
# ('http://www.wikidata.org/entity/Q18599390', '73D81')
# ('http://www.wikidata.org/entity/Q19686445', '71F2453')
# ('http://www.wikidata.org/entity/Q19858352', '73D3142')
# ('http://www.wikidata.org/entity/Q19858354', '73D315')
# ('http://www.wikidata.org/entity/Q19858663', '12A436')
# ('http://www.wikidata.org/entity/Q19858830', '73E373')
# ('http://www.wikidata.org/entity/Q19925101', '11H(LUKE)')
# ('http://www.wikidata.org/entity/Q19926085', '71F314')
# ('http://www.wikidata.org/entity/Q19928105', '71D134')
# ('http://www.wikidata.org/entity/Q19960417', '12A436')
# ('http://www.wikidata.org/entity/Q20178156', '71P421')
# ('http://www.wikidata.org/entity/Q20179470', '71P3411')
# ('http://www.wikidata.org/entity/Q20553749', '73D7212(+3)')
# ('http://www.wikidata.org/entity/Q20771738', '71G2141')
# ('http://www.wikidata.org/entity/Q20808513', '48A8111')
# ('http://www.wikidata.org/entity/Q20810150', '71P3411')
# ('http://www.wikidata.org/entity/Q20810150', '71P4333')
# ('http://www.wikidata.org/entity/Q21074996', '71F314')
# ('http://www.wikidata.org/entity/Q21281980', '12A436')
# ('http://www.wikidata.org/entity/Q21485158', '71D134')
# ('http://www.wikidata.org/entity/Q21515204', '71F314')
# ('http://www.wikidata.org/entity/Q21600849', '41B32')
# ('http://www.wikidata.org/entity/Q21600959', '41B32')
# ('http://www.wikidata.org/entity/Q21600959', '42D231')
# ('http://www.wikidata.org/entity/Q21665583', '73D315')
# ('http://www.wikidata.org/entity/Q21711948', '71B35211')
# ('http://www.wikidata.org/entity/Q21727569', '71F2453')
# ('http://www.wikidata.org/entity/Q21740542', '73B2')
# ('http://www.wikidata.org/entity/Q21753895', '73D3142')
# ('http://www.wikidata.org/entity/Q21764210', '73DD643')
# ('http://www.wikidata.org/entity/Q22260425', '73E373')
# ('http://www.wikidata.org/entity/Q22287786', '71Q62')
# ('http://www.wikidata.org/entity/Q22329816', '73D81')
# ('http://www.wikidata.org/entity/Q22340984', '71P421')
# ('http://www.wikidata.org/entity/Q22672532', '73B65(+3)')
# ('http://www.wikidata.org/entity/Q22712843', '71P3411')
# ('http://www.wikidata.org/entity/Q22945654', '73E15')
# ('http://www.wikidata.org/entity/Q23063956', '71T52')
# ('http://www.wikidata.org/entity/Q23928490', '73D81')
# ('http://www.wikidata.org/entity/Q23935694', '11H(JAMES THE LESS)0')
# ('http://www.wikidata.org/entity/Q23935694', '11H(PAUL)0')
# ('http://www.wikidata.org/entity/Q26037148', '48A8111')
# ('http://www.wikidata.org/entity/Q26037148', '48C5141')
# ('http://www.wikidata.org/entity/Q26197833', '11H(LUKE)')
# ('http://www.wikidata.org/entity/Q26221225', '25H16')
# ('http://www.wikidata.org/entity/Q26492678', '73D7212(+3)')
# ('http://www.wikidata.org/entity/Q27697241', '73D3142')
# ('http://www.wikidata.org/entity/Q27701852', '73D7212(+3)')
# ('http://www.wikidata.org/entity/Q27701863', '73D7212(+3)')
# ('http://www.wikidata.org/entity/Q27974869', '73B65(+3)')
# ('http://www.wikidata.org/entity/Q27978392', '73B2')
# ('http://www.wikidata.org/entity/Q27980845', '73B2')
# ('http://www.wikidata.org/entity/Q27981613', '73D81')
# ('http://www.wikidata.org/entity/Q27997164', '25H16')
# ('http://www.wikidata.org/entity/Q27998254', '25H16')
# ('http://www.wikidata.org/entity/Q28001915', '25H16')
# ('http://www.wikidata.org/entity/Q28001975', '25H16')
# ('http://www.wikidata.org/entity/Q28005262', '44B191')
# ('http://www.wikidata.org/entity/Q28008191', '43C58')
# ('http://www.wikidata.org/entity/Q29480665', '73D634')
# ('http://www.wikidata.org/entity/Q28002077', '25H16')
# ('http://www.wikidata.org/entity/Q28004411', '71B35211')
# ('http://www.wikidata.org/entity/Q28005106', '25H16')
# ('http://www.wikidata.org/entity/Q28006821', '25H16')
# ('http://www.wikidata.org/entity/Q28008343', '25H16')
# ('http://www.wikidata.org/entity/Q28008506', '25H16')
# ('http://www.wikidata.org/entity/Q28008507', '25H16')
# ('http://www.wikidata.org/entity/Q28796947', '12A436')
# ('http://www.wikidata.org/entity/Q29953135', '71F2453')
# ('http://www.wikidata.org/entity/Q33123458', '71F2453')
# ('http://www.wikidata.org/entity/Q323141', '61B2(JAKOB HELLER)')
# ('http://www.wikidata.org/entity/Q323141', '61B2(KATHARINA HELLER)')
# ('http://www.wikidata.org/entity/Q335774', '25D23')
# ('http://www.wikidata.org/entity/Q354396', '41A7212(+4)')
# ('http://www.wikidata.org/entity/Q354396', '61BB2(BLOCH-BAUER,Adele)11')
# ('http://www.wikidata.org/entity/Q387377', '43C(+11)')
# ('http://www.wikidata.org/entity/Q387377', '61D(TAYGETOS)')
# ('http://www.wikidata.org/entity/Q387377', '61E(SPARTA)')
# ('http://www.wikidata.org/entity/Q387377', '98B(LYCURGUS)(+1)')
# ('http://www.wikidata.org/entity/Q421716', '31A(+64)')
# ('http://www.wikidata.org/entity/Q462688', '61D(GARDEN OF THE TUILERIES)')
# ('http://www.wikidata.org/entity/Q471289', '31A4632')
# ('http://www.wikidata.org/entity/Q471289', '31D12')
# ('http://www.wikidata.org/entity/Q471289', '46C1272')
# ('http://www.wikidata.org/entity/Q488825', '61B2(MEDICI, Cosimo de)(+1)')
# ('http://www.wikidata.org/entity/Q488825', '61B2(MEDICI, Giovanni di Cosimo de)(+1)')
# ('http://www.wikidata.org/entity/Q488825', '61B2(MEDICI, Piero di Cosimo de)(+1)')
# ('http://www.wikidata.org/entity/Q1055111', '11F721')
# ('http://www.wikidata.org/entity/Q1114913', '31A41')
# ('http://www.wikidata.org/entity/Q1115595', '73BB6412')
# ('http://www.wikidata.org/entity/Q1516449', '48C145')
# ('http://www.wikidata.org/entity/Q2354080', '73C21')
# ('http://www.wikidata.org/entity/Q2389534', '11H(GILES)')
# ('http://www.wikidata.org/entity/Q2480921', '11P3114')
# ('http://www.wikidata.org/entity/Q2480921', '11Q7131(CHOIR)')
# ('http://www.wikidata.org/entity/Q2480921', '11Q71462')
# ('http://www.wikidata.org/entity/Q2480921', '61B2(...)12')
# ('http://www.wikidata.org/entity/Q2875363', '73F2423')
# ('http://www.wikidata.org/entity/Q2875363', '73F2424')
# ('http://www.wikidata.org/entity/Q2875363', '73F2425')
# ('http://www.wikidata.org/entity/Q3213791', '11FF4222(+5)')
# ('http://www.wikidata.org/entity/Q3605568', '73B22')
# ('http://www.wikidata.org/entity/Q3697647', '73D756')
# ('http://www.wikidata.org/entity/Q3698187', '73D641(+3)')
# ('http://www.wikidata.org/entity/Q3698215', '73D634')
# ('http://www.wikidata.org/entity/Q3714311', '73E75')
# ('http://www.wikidata.org/entity/Q3736323', '11I62(EZEKIEL)')
# ('http://www.wikidata.org/entity/Q3771662', '71D135')
# ('http://www.wikidata.org/entity/Q3925593', '71Q75')
# ('http://www.wikidata.org/entity/Q3927386', '11HH(MARTHA)0')
# ('http://www.wikidata.org/entity/Q3933555', '73E14')
# ('http://www.wikidata.org/entity/Q3945921', '11II4')
# ('http://www.wikidata.org/entity/Q3947332', '11H(JOSEPH)(+5)')
# ('http://www.wikidata.org/entity/Q3947596', '11H(MARK)832')
# ('http://www.wikidata.org/entity/Q3947824', '11H(PETER)7')
# ('http://www.wikidata.org/entity/Q3955632', '71A22')
# ('http://www.wikidata.org/entity/Q3955636', '71A21')
# ('http://www.wikidata.org/entity/Q3974456', '71D12')
# ('http://www.wikidata.org/entity/Q4473607', '73D35121(+5)')
# ('http://www.wikidata.org/entity/Q5416129', '31F25')
# ('http://www.wikidata.org/entity/Q5694403', '73F2215')
# ('http://www.wikidata.org/entity/Q9048912', '31A523')
# ('http://www.wikidata.org/entity/Q9048912', '48C51111')
# ('http://www.wikidata.org/entity/Q9068317', '73C522')
# ('http://www.wikidata.org/entity/Q9202855', '71Q7211')
# ('http://www.wikidata.org/entity/Q11827829', '11Q51')
# ('http://www.wikidata.org/entity/Q15965547', '73D641(+3)')
# ('http://www.wikidata.org/entity/Q16168319', '73AA522(+13)')
# ('http://www.wikidata.org/entity/Q16960276', '11I62(ADAM AND EVE)')
# ('http://www.wikidata.org/entity/Q17319846', '25G21(ORANGE)')
# ('http://www.wikidata.org/entity/Q17319905', '47I2142')
# ('http://www.wikidata.org/entity/Q17320928', '41D252(CAP)')
# ('http://www.wikidata.org/entity/Q17320928', '42E1')
# ('http://www.wikidata.org/entity/Q17320966', '46C1311')
# ('http://www.wikidata.org/entity/Q17321321', '25F24(DEER)(+64)')
# ('http://www.wikidata.org/entity/Q17323780', '43C11311')
# ('http://www.wikidata.org/entity/Q17323880', '41C711')
# ('http://www.wikidata.org/entity/Q17324783', '33A13')
# ('http://www.wikidata.org/entity/Q17327359', '25F711(LADYBIRD)')
# ('http://www.wikidata.org/entity/Q17327412', '48C7551')
# ('http://www.wikidata.org/entity/Q17328107', '42B742')
# ('http://www.wikidata.org/entity/Q17329732', '54DD311')
# ('http://www.wikidata.org/entity/Q17334830', '45F5')
# ('http://www.wikidata.org/entity/Q17335599', '48C524')
# ('http://www.wikidata.org/entity/Q17335922', '43C58')
# ('http://www.wikidata.org/entity/Q17341472', '25L0')
# ('http://www.wikidata.org/entity/Q17341472', '46B4941')
# ('http://www.wikidata.org/entity/Q17341630', '11H(CHARLES BORROMEO)0')
# ('http://www.wikidata.org/entity/Q17341816', '48CC521')
# ('http://www.wikidata.org/entity/Q17342080', '43C1132')
# ('http://www.wikidata.org/entity/Q17342888', '48C241')
# ('http://www.wikidata.org/entity/Q17342988', '44B19')
# ('http://www.wikidata.org/entity/Q17343191', '44B191')
# ('http://www.wikidata.org/entity/Q17347340', '42B742')
# ('http://www.wikidata.org/entity/Q17347662', '44A3')
# ('http://www.wikidata.org/entity/Q18572534', '71Q75')
# ('http://www.wikidata.org/entity/Q19858774', '73D3222')
# ('http://www.wikidata.org/entity/Q19858808', '73D634')
# ('http://www.wikidata.org/entity/Q19906253', '73B22')
# ('http://www.wikidata.org/entity/Q19913021', '73D641(+3)')

# %%
from random import sample
sampledresults = sample(triples_list, 33)
print(len(sampledresults))
# Out:
# 33

# %%
with open("semantic_validity3_wd.csv", mode='a') as my_file: 
  my_file = csv.writer(my_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_ALL)
  for triple in sampledresults:
      my_file.writerow(triple)

# %% [markdown]
# ## Sari

# %%
artwork_types= """<https://d-nb.info/gnd/4046277-8> <https://d-nb.info/gnd/4127900-1> <https://d-nb.info/gnd/4036042-8> <https://d-nb.info/gnd/4010427-8> <https://d-nb.info/gnd/4124432-1> <https://d-nb.info/gnd/4123412-1> <https://d-nb.info/gnd/4131808-0> <https://d-nb.info/gnd/4124432-1> <https://d-nb.info/gnd/4114333-4> <https://d-nb.info/gnd/4033760-1> <https://d-nb.info/gnd/4002511-1> <https://d-nb.info/gnd/4627787-0> <https://d-nb.info/gnd/4029783-4> <https://d-nb.info/gnd/4006627-7> <https://d-nb.info/gnd/4064542-3> <https://d-nb.info/gnd/4229053-3>"""
variables = ["art", "art_label", "subj"]

# %%
# sari. No labels available for subjects. 

sari_query1 = """
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX getty: <http://vocab.getty.edu/ontology#>
PREFIX gndo: <https://d-nb.info/standards/elementset/gnd#>
  
SELECT DISTINCT ?art ?art_label (sample(?s) as ?subj) WHERE {
VALUES ?type {"""+artwork_types+"""}
  # ?art gndo:formOfWorkAndExpression ?type; 
    gndo:preferredNameForTheWork ?art_label; 
    gndo:topic ?s. # gndo:gndSubjectCategory
   # FILTER(lang(?art_label)='en')

  
} GROUP BY ?art ?art_label ?subj
  ORDER BY RAND()
  LIMIT 50


"""
sari_query2 = """
PREFIX gndo: <https://d-nb.info/standards/elementset/gnd#>
  
SELECT DISTINCT ?art ?art_label (sample(?s) as ?subj) WHERE {
VALUES ?type {"""+artwork_types+"""}
  # ?art gndo:formOfWorkAndExpression ?type; 
    gndo:preferredNameForTheWork ?art_label; 
    gndo:gndSubjectCategory ?s. # gndo:gndSubjectCategory
   # FILTER(lang(?art_label)='en')

  
} GROUP BY ?art ?art_label ?subj
  ORDER BY RAND()
  LIMIT 94


"""


recall1 = sample_selection("semantic_validity_sari.csv", sari_query1, sari_endpoint, variables)
recall2 = sample_selection("semantic_validity_sari.csv", sari_query2, sari_endpoint, variables)

# %% [markdown]
# ## Arco
# Since we have 5 relations identifying a subject, we select 20 artworks/subjects per relation, for a total of 100 artworks/subjects.

# %%
import csv
with open('Arco_semantic_validity.csv', mode='w') as my_file:
  arco_file = csv.writer(my_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_ALL)
  arco_file.writerow(['Artwork', 'Artwork_label', "Subject", 'Subject_label'])

# %%
relations = ["arco-cd:hasSubject",	"arco-cd:iconclassCode", "arco-cd:subject", "dc:subject"]
# this query can sometimes return server error
# open csv, store the results of every iteration there. 
with open('Arco_semantic_validity.csv', mode='a') as my_file: 
  my_file = csv.writer(my_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_ALL)

  for rel in relations: 
    arco_query = """

    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX arco-cd: <https://w3id.org/arco/ontology/context-description/>
    PREFIX arco-dd: <https://w3id.org/arco/ontology/denotative-description/>
    PREFIX arco: <https://w3id.org/arco/ontology/arco/>
    PREFIX dc: <http://purl.org/dc/elements/1.1/>

    SELECT distinct ?art (sample(?art_label) as ?a_label) ?subj ?subj_label
    WHERE {
    # ?art a arco:HistoricOrArtisticProperty. 
     # ?art """+rel+""" ?subj; rdfs:label ?art_label.
    OPTIONAL {?subj rdfs:label ?subj_label}.
   # FILTER(lang(?art_label)='en')
   # FILTER(lang(?subj_label)='en')
    }
    GROUP BY ?art ?subj ?subj_label
    ORDER BY RAND()
    LIMIT 20
    """


    res = sparl_query_setting(arco_query, arco_endpoint)
    
    # manipulate the result
    for result in res["results"]["bindings"]:
      print(result)
      if "subj_label" not in result: 
        subj_label = "none"
      else:
        subj_label = result["subj_label"]["value"]
      my_file.writerow([result["art"]["value"], result["a_label"]["value"], result["subj"]["value"], subj_label])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/SPARQLWrapper/Wrapper.py in _query(self)
#     925             else:
# --> 926                 response = urlopener(request)
#     927             return response, self.returnFormat
#
# /usr/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# /usr/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# /usr/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#
# /usr/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# /usr/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /usr/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 500: SPARQL Request Failed
#
# During handling of the above exception, another exception occurred:
#
# EndPointInternalError                     Traceback (most recent call last)
# <ipython-input-11-d24a04ec390f> in <module>()
#      28
#      29
# ---> 30     res = sparl_query_setting(arco_query, arco_endpoint)
#      31
#      32     # manipulate the result
#
# <ipython-input-2-23da2ac34093> in sparl_query_setting(query, endpoint)
#       6   sparql.setReturnFormat(JSON)
#       7   # get the results
# ----> 8   results = sparql.query().convert()
#       9   return results
#
# /usr/local/lib/python3.7/dist-packages/SPARQLWrapper/Wrapper.py in query(self)
#     958         :rtype: :class:`QueryResult` instance
#     959         """
# --> 960         return QueryResult(self._query())
#     961
#     962     def queryAndConvert(self) -> "QueryResult.ConvertResult":
#
# /usr/local/lib/python3.7/dist-packages/SPARQLWrapper/Wrapper.py in _query(self)
#     936                 raise URITooLong(e.read())
#     937             elif e.code == 500:
# --> 938                 raise EndPointInternalError(e.read())
#     939             else:
#     940                 raise e
#
# EndPointInternalError: EndPointInternalError: The endpoint returned the HTTP status code 500.
#
# Response:
# b"Virtuoso S1T00 Error SR171: Transaction timed out\n\nSPARQL query:\ndefine sql:big-data-const 0 \n#output-format:application/sparql-results+json\n\n\n    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>\n    PREFIX arco-cd: <https://w3id.org/arco/ontology/context-description/>\n    PREFIX arco-dd: <https://w3id.org/arco/ontology/denotative-description/>\n    PREFIX arco: <https://w3id.org/arco/ontology/arco/>\n    PREFIX dc: <http://purl.org/dc/elements/1.1/>\n\n    SELECT distinct ?art (sample(?art_label) as ?a_label) ?subj ?subj_label\n    WHERE {\n    ?art a arco:HistoricOrArtisticProperty. \n     ?art arco-cd:hasSubject ?subj; rdfs:label ?art_label.\n    OPTIONAL {?subj rdfs:label ?subj_label}.\n   # FILTER(lang(?art_label)='en')\n   # FILTER(lang(?subj_label)='en')\n    }\n    GROUP BY ?art ?subj ?subj_label\n    ORDER BY RAND()\n    LIMIT 20\n    "

# %%
variables = ["art", "a_label", "subj", "subj_label"]

iconogr_apparatus_query = """
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX arco-cd: <https://w3id.org/arco/ontology/context-description/>
    PREFIX arco-dd: <https://w3id.org/arco/ontology/denotative-description/>
    PREFIX arco: <https://w3id.org/arco/ontology/arco/>
    PREFIX dc: <http://purl.org/dc/elements/1.1/>

    SELECT distinct ?art (sample(?art_label) as ?a_label) ?subj ?subj_label
    WHERE {
      VALUES ?rel {arco-cd:hasSubject arco-cd:iconclassCode arco-cd:subject dc:subject}
    # ?art a arco:HistoricOrArtisticProperty; 
      rdfs:label ?art_label. 
     # ?art arco-dd:hasIconographicOrDecorativeApparatus ?iconogr.
     # ?iconogr ?rel ?subj.
    OPTIONAL {?subj rdfs:label ?subj_label}.
    FILTER NOT EXISTS {?iconogr a arco-dd:DecorativeApparatus}
   # FILTER(lang(?art_label)='en')
   # FILTER(lang(?subj_label)='en')
    }
    GROUP BY ?art ?subj ?subj_label
    ORDER BY RAND()
    LIMIT 20
    """
recall = sample_selection("semantic_validity_arco.csv", iconogr_apparatus_query, arco_endpoint, variables)

# %% [markdown]
# # COLUMN COMPLETENESS SAMPLE

# %% [markdown]
# ## ARCO
#
# select 100 random works of art that have at least one of the subject properties
#
# then create a values query to group together all the subjects/iconographic elements associated with them

# %%
query100randomarco = '''PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX arco-cd: <https://w3id.org/arco/ontology/context-description/>
PREFIX arco-dd: <https://w3id.org/arco/ontology/denotative-description/>
PREFIX arco: <https://w3id.org/arco/ontology/arco/>
PREFIX datal: <https://w3id.org/arco/resource/Lombardia/HistoricOrArtisticProperty/>
PREFIX datas: <https://w3id.org/arco/resource/SARDEGNA/HistoricOrArtisticProperty/>
PREFIX data: <https://w3id.org/arco/resource/HistoricOrArtisticProperty/>


SELECT DISTINCT ?art where {
# ?art a arco:HistoricOrArtisticProperty ;
arco-cd:iconclassCode | dc:subject | arco-cd:subject | arco-dd:hasIconographicOrDecorativeApparatus ?subj .
} ORDER BY RAND ()
LIMIT 100'''

arco100randomresults = sparl_query_setting(query100randomarco, arco)

arcolist = []
for el in arco100randomresults["results"]["bindings"]:
  uri = str(el["art"]["value"])
  uri = "<" + uri + ">"
  arcolist.append(uri)
stringforvalues = " ".join(arcolist)

# %%
stringforvalues[:2000]
# Out:
# '<https://w3id.org/arco/resource/HistoricOrArtisticProperty/0900014470> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/0900341487> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/1500662743> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/0800202761> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/1300144187> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/2000052548> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/1600047946> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/0500447476> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/0900329809> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/0700008507> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/1100253326> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/1600183135> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/2000065321> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/0500446046> <https://w3id.org/arco/resource/SARDEGNA/HistoricOrArtisticProperty/2000225913> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/0800223044> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/1200759881> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/0800236259> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/0500653408> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/1600108281-5> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/0900146042> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/0900106259> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/1900139470> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/0500656484> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/0900527101> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/0300178124> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/0900054674> <https://w3id.org/arco/resource/HistoricOrArtisticProperty/1700040033> <'

# %%
querycolumnarcowithrandomvalues = '''
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX arco-cd: <https://w3id.org/arco/ontology/context-description/>
PREFIX arco-dd: <https://w3id.org/arco/ontology/denotative-description/>
PREFIX arco: <https://w3id.org/arco/ontology/arco/>
PREFIX datal: <https://w3id.org/arco/resource/Lombardia/HistoricOrArtisticProperty/>
PREFIX datas: <https://w3id.org/arco/resource/SARDEGNA/HistoricOrArtisticProperty/>
PREFIX data: <https://w3id.org/arco/resource/HistoricOrArtisticProperty/>


SELECT DISTINCT ?art (GROUP_CONCAT(?subj; separator = " @ " ) as ?subjects) where {
VALUES ?art { '''+ stringforvalues +''' }
# ?art arco-cd:iconclassCode | dc:subject | arco-cd:subject | arco-dd:hasIconographicOrDecorativeApparatus ?subj .
}'''

resultscolumnsarco = sparl_query_setting(querycolumnarcowithrandomvalues, arco)

# %%
import csv
makeatsv("arcocolumn.tsv", resultscolumnsarco, "art", "subjects")

# %% [markdown]
# ## DBpedia
#
# use built in order by rand()

# %%
qmdb2 = '''
prefix dbo: <http://dbpedia.org/ontology/>
prefix dct: <http://purl.org/dc/terms/>
prefix dbp: <http://dbpedia.org/property/>
SELECT ?artwork (group_concat(distinct ?subject1; separator=" @ ") as ?subjects1) (group_concat(distinct ?subject2; separator = " @ ") as ?subjects2) WHERE {
# ?artwork a dbo:Artwork;
dct:subject ?subject1;
dbp:subject ?subject2 . }
ORDER BY RAND()
LIMIT 100'''

rescoldb = sparl_query_setting(qmdb2, dbpedia)

# %%
with open("dbpedia_colc.tsv", "wt", encoding="utf-8-sig") as out_file:
  twriter = csv.writer(out_file, delimiter="\t")
  twriter.writerow(["artwork", "prop1", "prop2"])
  for res in rescoldb["results"]["bindings"]:
    art = res["artwork"]["value"]
    sub1 = res["subjects1"]["value"]
    sub2 = res["subjects2"]["value"]
    twriter.writerow([art, sub1, sub2])

# %% [markdown]
# ## Europeana
#
# take all the paintings - groupconcat(subjects) couples
#
# take all the sculptures - groupconcat(subjects) couples
#
# take a sample of 100 from the total

# %%
euroqueryp = '''
PREFIX ore: <http://www.openarchives.org/ore/terms/>
PREFIX edm: <http://www.europeana.eu/schemas/edm/>

select  ?CHO (GROUP_CONCAT(distinct ?sub ;separator=" @ ") as ?subjects) where {
             # ?s a <http://www.w3.org/2004/02/skos/core#Concept> ;
<http://www.w3.org/2004/02/skos/core#broader>* <http://vocab.getty.edu/aat/300033618> .
# ?CHO dc:type ?s ;
dc:subject ?sub . }'''

euroquerysc = '''
PREFIX ore: <http://www.openarchives.org/ore/terms/>
PREFIX edm: <http://www.europeana.eu/schemas/edm/>

select  ?CHO (GROUP_CONCAT(distinct ?sub ;separator=" @ ") as ?subjects) where {
             # ?s a <http://www.w3.org/2004/02/skos/core#Concept> ;
<http://www.w3.org/2004/02/skos/core#broader>* <http://vocab.getty.edu/aat/300047090> .
# ?CHO dc:type ?s ;
dc:subject ?sub . }'''

reseuro2p = sparl_query_setting(euroqueryp, euro)
reseuro2s = sparl_query_setting(euroquerysc, euro)

# %%
paintings2 = []
for res in reseuro2p["results"]["bindings"]:
  art = res["CHO"]["value"]
  subjects = res["subjects"]["value"]
  paintings2.append((art, subjects))
print(len(paintings2))
for res in reseuro2s["results"]["bindings"]:
  art = res["CHO"]["value"]
  subjects = res["subjects"]["value"]
  paintings2.append((art, subjects))
print(len(paintings2))
# Out:
# 3954
# 5250

# %%
sampledartworks2 = sample(paintings2, 100)

# %%
with open("europeanacolumn3.tsv", "wt", encoding="utf-8-sig") as out_file:
  twriter = csv.writer(out_file, delimiter="§")
  twriter.writerow(["artwork", "subject"])
  for artsub in sampledartworks2:
    art = artsub[0]
    sub = artsub[1]
    twriter.writerow([art, sub])

# %% [markdown]
# ## Yago

# %%
qy2 = '''
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>

SELECT distinct ?artwork (GROUP_CONCAT(distinct ?sub;separator = " @ ") as ?subjects)
WHERE {
  VALUES ?art {schema:Painting schema:Sculpture}
  # ?artwork rdf:type ?art ;
  schema:about ?sub 
} GROUP BY ?artwork
ORDER BY RAND()
LIMIT 100'''

ry2 = sparl_query_setting(qy2, yago)

# %%
makeatsv("yagocolumn.tsv", ry2, "artwork", "subjects")

# %% [markdown]
# ## ND HUNGARY

# %%
querynd2 = '''SELECT COUNT(distinct ?URI) as ?tot WHERE {
# ?URI <http://purl.org/dc/terms/type> dcmitype:Image ;
<http://purl.org/dc/terms/subject> ?sub .
 }'''

rndh2 = sparl_query_setting(querynd2, nd_hungary)
for result in rndh2["results"]["bindings"]:
  print(result["tot"]["value"])
# Out:
# 6523

# %%
resultsnd2 = set()
queryndsample = '''SELECT ?URI WHERE {
# ?URI <http://purl.org/dc/terms/type> dcmitype:Image ;
<http://purl.org/dc/terms/subject> ?sub .
 }LIMIT 1
 OFFSET @@n@@'''
while len(resultsnd2) < 100:
  randomn = random.randint(0, 6522)
  queryndrandom = queryndsample.replace("@@n@@", str(randomn))
  rndhsem = sparl_query_setting(queryndrandom, nd_hungary)
  for res in rndhsem["results"]["bindings"]:
    art = res["URI"]["value"]
    resultsnd2.add(art)

# %%
resultsnd2
# Out:
# {'http://lod.sztaki.hu/data/item/6188',
#  'http://lod.sztaki.hu/data/item/6215',
#  'http://lod.sztaki.hu/data/item/6224',
#  'http://lod.sztaki.hu/data/item/6231',
#  'http://lod.sztaki.hu/data/item/6234',
#  'http://lod.sztaki.hu/data/item/6350',
#  'http://lod.sztaki.hu/data/item/6379',
#  'http://lod.sztaki.hu/data/item/6402',
#  'http://lod.sztaki.hu/data/item/6421',
#  'http://lod.sztaki.hu/data/item/6423',
#  'http://lod.sztaki.hu/data/item/6499',
#  'http://lod.sztaki.hu/data/item/6678',
#  'http://lod.sztaki.hu/data/item/6689',
#  'http://lod.sztaki.hu/data/item/6690',
#  'http://lod.sztaki.hu/data/item/6706',
#  'http://lod.sztaki.hu/data/item/6708',
#  'http://lod.sztaki.hu/data/item/6720',
#  'http://lod.sztaki.hu/data/item/6723',
#  'http://lod.sztaki.hu/data/item/6755',
#  'http://lod.sztaki.hu/data/item/6761',
#  'http://lod.sztaki.hu/data/item/6793',
#  'http://lod.sztaki.hu/data/item/6916',
#  'http://lod.sztaki.hu/data/item/6936',
#  'http://lod.sztaki.hu/data/item/6949',
#  'http://lod.sztaki.hu/data/item/6959',
#  'http://lod.sztaki.hu/data/item/6969',
#  'http://lod.sztaki.hu/data/item/6974',
#  'http://lod.sztaki.hu/data/item/6976',
#  'http://lod.sztaki.hu/data/item/7004',
#  'http://lod.sztaki.hu/data/item/7105',
#  'http://lod.sztaki.hu/data/item/7109',
#  'http://lod.sztaki.hu/data/item/7129',
#  'http://lod.sztaki.hu/data/item/7145',
#  'http://lod.sztaki.hu/data/item/7171',
#  'http://lod.sztaki.hu/data/item/7179',
#  'http://lod.sztaki.hu/data/item/7246',
#  'http://lod.sztaki.hu/data/item/7267',
#  'http://lod.sztaki.hu/data/item/7276',
#  'http://lod.sztaki.hu/data/item/7288',
#  'http://lod.sztaki.hu/data/item/7292',
#  'http://lod.sztaki.hu/data/item/7295',
#  'http://lod.sztaki.hu/data/item/7305',
#  'http://lod.sztaki.hu/data/item/7313',
#  'http://lod.sztaki.hu/data/item/7336',
#  'http://lod.sztaki.hu/data/item/7413',
#  'http://lod.sztaki.hu/data/item/7486',
#  'http://lod.sztaki.hu/data/item/7520',
#  'http://lod.sztaki.hu/data/item/7540',
#  'http://lod.sztaki.hu/data/item/7541',
#  'http://lod.sztaki.hu/data/item/7558',
#  'http://lod.sztaki.hu/data/item/7561',
#  'http://lod.sztaki.hu/data/item/7598',
#  'http://lod.sztaki.hu/data/item/7613',
#  'http://lod.sztaki.hu/data/item/7673',
#  'http://lod.sztaki.hu/data/item/7680',
#  'http://lod.sztaki.hu/data/item/7685',
#  'http://lod.sztaki.hu/data/item/7732',
#  'http://lod.sztaki.hu/data/item/7742',
#  'http://lod.sztaki.hu/data/item/7886',
#  'http://lod.sztaki.hu/data/item/7894',
#  'http://lod.sztaki.hu/data/item/7900',
#  'http://lod.sztaki.hu/data/item/7940',
#  'http://lod.sztaki.hu/data/item/8010',
#  'http://lod.sztaki.hu/data/item/8020',
#  'http://lod.sztaki.hu/data/item/8024',
#  'http://lod.sztaki.hu/data/item/8042',
#  'http://lod.sztaki.hu/data/item/8050',
#  'http://lod.sztaki.hu/data/item/8123',
#  'http://lod.sztaki.hu/data/item/8147',
#  'http://lod.sztaki.hu/data/item/8242',
#  'http://lod.sztaki.hu/data/item/8247',
#  'http://lod.sztaki.hu/data/item/8254',
#  'http://lod.sztaki.hu/data/item/8257',
#  'http://lod.sztaki.hu/data/item/8370',
#  'http://lod.sztaki.hu/data/item/8405',
#  'http://lod.sztaki.hu/data/item/8407',
#  'http://lod.sztaki.hu/data/item/8416',
#  'http://lod.sztaki.hu/data/item/8437',
#  'http://lod.sztaki.hu/data/item/8531',
#  'http://lod.sztaki.hu/data/item/8569',
#  'http://lod.sztaki.hu/data/item/8577',
#  'http://lod.sztaki.hu/data/item/8627',
#  'http://lod.sztaki.hu/data/item/8631',
#  'http://lod.sztaki.hu/data/item/8715',
#  'http://lod.sztaki.hu/data/item/8769',
#  'http://lod.sztaki.hu/data/item/8789',
#  'http://lod.sztaki.hu/data/item/8945',
#  'http://lod.sztaki.hu/data/item/8955',
#  'http://lod.sztaki.hu/data/item/8972',
#  'http://lod.sztaki.hu/data/item/9035',
#  'http://lod.sztaki.hu/data/item/9061',
#  'http://lod.sztaki.hu/data/item/9072',
#  'http://lod.sztaki.hu/data/item/9148',
#  'http://lod.sztaki.hu/data/item/9161',
#  'http://lod.sztaki.hu/data/item/9175',
#  'http://lod.sztaki.hu/data/item/9189',
#  'http://lod.sztaki.hu/data/item/9191',
#  'http://lod.sztaki.hu/data/item/9238',
#  'http://lod.sztaki.hu/data/item/9241',
#  'http://lod.sztaki.hu/data/item/9257'}

# %%
artworkssub = dict()
samplequery = '''
SELECT distinct ?sub where {
@@@uri@@@ <http://purl.org/dc/terms/subject> ?sub .
}
'''
for el in resultsnd2:
  artworkssub[el] = []
  queryel = "<" + el + ">"
  querynd = samplequery.replace("@@@uri@@@", queryel)
  rndhsem = sparl_query_setting(querynd, nd_hungary)
  for res in rndhsem["results"]["bindings"]:
    sub = res["sub"]["value"]
    artworkssub[el].append(sub)

# %%
artworkssub
# Out:
# {'http://lod.sztaki.hu/data/item/6188': ['plakát',
#   'eredeti',
#   'Matejko, Theo (1893-1944)',
#   'német',
#   'műtárgy',
#   'plakátművészet',
#   '20. század első fele'],
#  'http://lod.sztaki.hu/data/item/6215': ['eredeti',
#   'férfi',
#   'fényképek',
#   '20. század eleje',
#   'akt',
#   'fotóművészet'],
#  'http://lod.sztaki.hu/data/item/6224': ['olasz',
#   'eredeti',
#   'fénykép',
#   'reneszánsz',
#   'Raffaello di Giovanni Santi (1483-1520)',
#   'festészet 16. sz. eleje',
#   'fotóművészet',
#   'műtárgyfotó 19. sz. vége'],
#  'http://lod.sztaki.hu/data/item/6231': ['olasz',
#   'eredeti',
#   'fénykép',
#   'reneszánsz',
#   'freskó',
#   'Correggio (1489-1534)',
#   'fotóművészet',
#   'műtárgyfotó 19. sz. vége',
#   'festészet 16. sz. első harmada'],
#  'http://lod.sztaki.hu/data/item/6234': ['olasz',
#   'eredeti',
#   'fénykép',
#   'reneszánsz',
#   'freskó',
#   'Correggio (1489-1534)',
#   'fotóművészet',
#   'műtárgyfotó 19. sz. vége',
#   'festészet 16. sz. első harmada'],
#  'http://lod.sztaki.hu/data/item/6350': ['eredeti',
#   'fénykép',
#   'ipari fotó 20. sz. eleje',
#   'háziipar',
#   'kötél',
#   'kötélgyártás',
#   'fotóművészet'],
#  'http://lod.sztaki.hu/data/item/6379': ['szecesszió',
#   'plakát',
#   'eredeti',
#   'német',
#   'Hohlwein, Ludwig (1874-1949)',
#   'műtárgy',
#   'plakátművészet'],
#  'http://lod.sztaki.hu/data/item/6402': ['olasz',
#   'eredeti',
#   'fénykép',
#   'Michelangelo Buonarroti (1475-1564)',
#   'festészet',
#   'freskó',
#   'mappa',
#   'fotóművészet',
#   'műtárgyfotó 19. század vége'],
#  'http://lod.sztaki.hu/data/item/6421': ['eredeti',
#   'fénykép',
#   'épületfotó 19. század vége',
#   'városfotó 19. század vége',
#   'lengyel',
#   'templom',
#   'oltár',
#   'fotóművészet',
#   'műemlék'],
#  'http://lod.sztaki.hu/data/item/6423': ['eredeti',
#   'fénykép',
#   'mappa',
#   'fotóművészet',
#   'műtárgyfotó 19. század vége'],
#  'http://lod.sztaki.hu/data/item/6499': ['eredeti',
#   'magyar',
#   'fénykép',
#   'mappa',
#   'fotóművészet',
#   'műtárgyfotó 19. század vége',
#   'iparművészet',
#   'bőrdíszművesség'],
#  'http://lod.sztaki.hu/data/item/6678': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   '1921-1929'],
#  'http://lod.sztaki.hu/data/item/6689': ['grafika',
#   'eredeti',
#   'magyar',
#   'linóleummetszet',
#   'önarckép',
#   '1921-1929'],
#  'http://lod.sztaki.hu/data/item/6690': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   '1921-1929'],
#  'http://lod.sztaki.hu/data/item/6706': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   '1921-1929'],
#  'http://lod.sztaki.hu/data/item/6708': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   '1921-1929'],
#  'http://lod.sztaki.hu/data/item/6720': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   'arckép',
#   '1921-1929'],
#  'http://lod.sztaki.hu/data/item/6723': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   '1921-1929'],
#  'http://lod.sztaki.hu/data/item/6755': ['grafika',
#   'eredeti',
#   'magyar',
#   '1921-1929',
#   'cinkkarc',
#   'nőábrázolás'],
#  'http://lod.sztaki.hu/data/item/6761': ['grafika',
#   'eredeti',
#   'magyar',
#   'linóleummetszet',
#   '1921-1929'],
#  'http://lod.sztaki.hu/data/item/6793': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   '1921-1929',
#   'város'],
#  'http://lod.sztaki.hu/data/item/6916': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   '1921-1929',
#   'nőábrázolás'],
#  'http://lod.sztaki.hu/data/item/6936': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   'ábrázolása',
#   '1921-1929',
#   'munka'],
#  'http://lod.sztaki.hu/data/item/6949': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   '1921-1929',
#   'allegorikus ábrázolás'],
#  'http://lod.sztaki.hu/data/item/6959': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   'tájkép',
#   '1921-1929'],
#  'http://lod.sztaki.hu/data/item/6969': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   'ábrázolása',
#   'életkép',
#   'állatábrázolás',
#   'emberábrázolás',
#   '1921-1929',
#   'munka'],
#  'http://lod.sztaki.hu/data/item/6974': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   'ábrázolása',
#   '1921-1929',
#   'munka'],
#  'http://lod.sztaki.hu/data/item/6976': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   'Beethoven, Ludwig van (1770-1827)',
#   'emberábrázolás',
#   '1921-1929'],
#  'http://lod.sztaki.hu/data/item/7004': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   'életkép',
#   '1921-1929'],
#  'http://lod.sztaki.hu/data/item/7105': ['grafika',
#   'eredeti',
#   'magyar',
#   '1906-1914',
#   'linóleummetszet'],
#  'http://lod.sztaki.hu/data/item/7109': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   'arckép',
#   '1906-1914'],
#  'http://lod.sztaki.hu/data/item/7129': ['grafika',
#   'eredeti',
#   'magyar',
#   '1906-1914',
#   'linóleummetszet',
#   'életkép',
#   'játék'],
#  'http://lod.sztaki.hu/data/item/7145': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   '1906-1914',
#   'ábrázolása',
#   'munka'],
#  'http://lod.sztaki.hu/data/item/7171': ['grafika',
#   'eredeti',
#   '1893',
#   'magyar',
#   'szén',
#   'kréta'],
#  'http://lod.sztaki.hu/data/item/7179': ['grafika',
#   'eredeti',
#   'magyar',
#   'kréta',
#   '1880-1890'],
#  'http://lod.sztaki.hu/data/item/7246': ['grafika',
#   'eredeti',
#   'magyar',
#   'fa',
#   'tájkép',
#   'növényábrázolás',
#   '1931-1949',
#   'tusrajz',
#   'tollrajz'],
#  'http://lod.sztaki.hu/data/item/7267': ['grafika',
#   'eredeti',
#   'magyar',
#   '1931-1949',
#   'ceruzarajz'],
#  'http://lod.sztaki.hu/data/item/7276': ['grafika',
#   'eredeti',
#   'magyar',
#   'akt',
#   '1931-1949',
#   'tusrajz',
#   'tollrajz',
#   'nőábrázolás'],
#  'http://lod.sztaki.hu/data/item/7288': ['grafika',
#   'eredeti',
#   'magyar',
#   'akt',
#   '1931-1949',
#   'ceruzarajz',
#   'nőábrázolás'],
#  'http://lod.sztaki.hu/data/item/7292': ['grafika',
#   'eredeti',
#   'magyar',
#   'arckép',
#   '1931-1949',
#   'akvarell',
#   'nőábrázolás'],
#  'http://lod.sztaki.hu/data/item/7295': ['grafika',
#   'eredeti',
#   'magyar',
#   'arckép',
#   'emberábrázolás',
#   '1931-1949',
#   'szénrajz'],
#  'http://lod.sztaki.hu/data/item/7305': ['grafika',
#   'eredeti',
#   'magyar',
#   'életkép',
#   'emberábrázolás',
#   '1931-1949',
#   'tusrajz',
#   'tollrajz'],
#  'http://lod.sztaki.hu/data/item/7313': ['grafika',
#   'eredeti',
#   'magyar',
#   '1906-1914',
#   'litográfia'],
#  'http://lod.sztaki.hu/data/item/7336': ['grafika',
#   'eredeti',
#   'magyar',
#   '1906-1914',
#   'életkép',
#   'hidegtű'],
#  'http://lod.sztaki.hu/data/item/7413': ['grafika',
#   'eredeti',
#   'magyar',
#   'fametszet',
#   'bibliai jelenetek',
#   'Újszövetség',
#   '1931-1949',
#   'Madonna-ábrázolás'],
#  'http://lod.sztaki.hu/data/item/7486': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   'ábrázolása',
#   '1931-1949',
#   'munka',
#   'mezőgazdaság'],
#  'http://lod.sztaki.hu/data/item/7520': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   'akt',
#   '1931-1949',
#   'nőábrázolás'],
#  'http://lod.sztaki.hu/data/item/7540': ['grafika',
#   'eredeti',
#   'magyar',
#   'arckép',
#   '1931-1949',
#   'hidegtű'],
#  'http://lod.sztaki.hu/data/item/7541': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   'arckép',
#   '1931-1949'],
#  'http://lod.sztaki.hu/data/item/7558': ['grafika',
#   'eredeti',
#   'magyar',
#   'akt',
#   'fametszet',
#   '1931-1949',
#   'nőábrázolás'],
#  'http://lod.sztaki.hu/data/item/7561': ['grafika',
#   'eredeti',
#   'magyar',
#   'arckép',
#   'fametszet',
#   '1931-1949'],
#  'http://lod.sztaki.hu/data/item/7598': ['grafika',
#   'eredeti',
#   'magyar',
#   '1931-1949',
#   'mezzotinta',
#   'nőábrázolás'],
#  'http://lod.sztaki.hu/data/item/7613': ['grafika',
#   'eredeti',
#   'magyar',
#   'ábrázolása',
#   'linóleummetszet',
#   '1931-1949',
#   'munka'],
#  'http://lod.sztaki.hu/data/item/7673': ['grafika',
#   'eredeti',
#   'magyar',
#   'foltmaratás',
#   '1931-1949',
#   'népviselet',
#   'nőábrázolás'],
#  'http://lod.sztaki.hu/data/item/7680': ['grafika',
#   'eredeti',
#   'magyar',
#   'fametszet',
#   '1931-1949',
#   'szentek',
#   'Benedek, Szent'],
#  'http://lod.sztaki.hu/data/item/7685': ['grafika',
#   'eredeti',
#   'magyar',
#   'fametszet',
#   'bibliai jelenetek',
#   'Újszövetség',
#   '1931-1949',
#   'Krisztus-ábrázolás'],
#  'http://lod.sztaki.hu/data/item/7732': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   'emberábrázolás',
#   '1931-1949'],
#  'http://lod.sztaki.hu/data/item/7742': ['grafika',
#   'eredeti',
#   'magyar',
#   'fametszet',
#   'ex libris',
#   '1931-1949'],
#  'http://lod.sztaki.hu/data/item/7886': ['grafika',
#   'eredeti',
#   'magyar',
#   'linóleummetszet',
#   'emberábrázolás',
#   '1921-1929'],
#  'http://lod.sztaki.hu/data/item/7894': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   '1906-1914'],
#  'http://lod.sztaki.hu/data/item/7900': ['grafika',
#   'eredeti',
#   'magyar',
#   '1906-1914',
#   'linóleummetszet',
#   'mitológiai ábrázolás'],
#  'http://lod.sztaki.hu/data/item/7940': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'német',
#   '1883'],
#  'http://lod.sztaki.hu/data/item/8010': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   'ábrázolása',
#   '1921-1929',
#   'anyaság'],
#  'http://lod.sztaki.hu/data/item/8020': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   'ábrázolása',
#   '1921-1929',
#   'munka',
#   'mezőgazdaság'],
#  'http://lod.sztaki.hu/data/item/8024': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   '1921-1929',
#   'bibliai jelenetek',
#   'Újszövetség'],
#  'http://lod.sztaki.hu/data/item/8042': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   'ábrázolása',
#   '1921-1929',
#   'kikötő'],
#  'http://lod.sztaki.hu/data/item/8050': ['grafika',
#   'eredeti',
#   'magyar',
#   '1921-1929',
#   'magasmaratás'],
#  'http://lod.sztaki.hu/data/item/8123': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   'látkép',
#   '1931-1949'],
#  'http://lod.sztaki.hu/data/item/8147': ['grafika',
#   'eredeti',
#   'magyar',
#   'fametszet',
#   'iniciálé',
#   '1931-1949'],
#  'http://lod.sztaki.hu/data/item/8242': ['grafika',
#   'eredeti',
#   'magyar',
#   'fametszet',
#   '1931-1949',
#   'anyaság',
#   'gyermekábrázolás',
#   'nőábrázolás'],
#  'http://lod.sztaki.hu/data/item/8247': ['grafika',
#   'eredeti',
#   'magyar',
#   'fametszet',
#   'emberábrázolás',
#   '1931-1949',
#   'Böcklin, Arnold (1827-1901)'],
#  'http://lod.sztaki.hu/data/item/8254': ['grafika',
#   'eredeti',
#   'magyar',
#   '1931-1949',
#   'nőábrázolás',
#   'hidegtű'],
#  'http://lod.sztaki.hu/data/item/8257': ['grafika',
#   'eredeti',
#   'magyar',
#   'akt',
#   '1931-1949',
#   'nőábrázolás',
#   'hidegtű'],
#  'http://lod.sztaki.hu/data/item/8370': ['grafika',
#   'eredeti',
#   'magyar',
#   '1930',
#   'akvarell'],
#  'http://lod.sztaki.hu/data/item/8405': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   '1921-1929'],
#  'http://lod.sztaki.hu/data/item/8407': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   'arckép',
#   'emberábrázolás',
#   '1921-1929',
#   'Imre József (1851-1933)'],
#  'http://lod.sztaki.hu/data/item/8416': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   'arckép',
#   '1921-1929'],
#  'http://lod.sztaki.hu/data/item/8437': ['grafika',
#   'rézkarc',
#   'eredeti',
#   'magyar',
#   'tájkép',
#   '1921-1929'],
#  'http://lod.sztaki.hu/data/item/8531': ['grafika',
#   'eredeti',
#   'magyar',
#   '1922',
#   'akvarell'],
#  'http://lod.sztaki.hu/data/item/8569': ['grafika',
#   'eredeti',
#   'magyar',
#   'szén',
#   'kréta',
#   '1886-1891'],
#  'http://lod.sztaki.hu/data/item/8577': ['grafika',
#   'eredeti',
#   'magyar',
#   '1886',
#   'szén',
#   'kréta'],
#  'http://lod.sztaki.hu/data/item/8627': ['grafika',
#   'eredeti',
#   'magyar',
#   'akt',
#   'drapériatanulmány'],
#  'http://lod.sztaki.hu/data/item/8631': ['grafika',
#   'eredeti',
#   'magyar',
#   'akt',
#   '19. század vége',
#   'ceruza',
#   'kréta'],
#  'http://lod.sztaki.hu/data/item/8715': ['grafika',
#   'eredeti',
#   'magyar',
#   'akt',
#   '19. század vége',
#   'ceruza'],
#  'http://lod.sztaki.hu/data/item/8769': ['grafika',
#   'eredeti',
#   'magyar',
#   'arckép',
#   '20. század eleje',
#   'szénrajz',
#   'nőábrázolás'],
#  'http://lod.sztaki.hu/data/item/8789': ['grafika',
#   'eredeti',
#   'magyar',
#   'arckép',
#   'szénrajz',
#   '19. század vége-20. század eleje'],
#  'http://lod.sztaki.hu/data/item/8945': ['grafika',
#   'eredeti',
#   'magyar',
#   'ceruza'],
#  'http://lod.sztaki.hu/data/item/8955': ['grafika',
#   'eredeti',
#   'magyar',
#   'ceruza',
#   'kréta'],
#  'http://lod.sztaki.hu/data/item/8972': ['grafika',
#   'eredeti',
#   'magyar',
#   'növényábrázolás',
#   'ceruza'],
#  'http://lod.sztaki.hu/data/item/9035': ['grafika',
#   'eredeti',
#   'magyar',
#   'tájkép',
#   'ceruza',
#   '1842'],
#  'http://lod.sztaki.hu/data/item/9061': ['grafika',
#   'eredeti',
#   'magyar',
#   'tájkép',
#   'ceruza',
#   '1850-es évek'],
#  'http://lod.sztaki.hu/data/item/9072': ['grafika',
#   'eredeti',
#   'magyar',
#   'tájkép',
#   'ceruza',
#   '1850-es évek'],
#  'http://lod.sztaki.hu/data/item/9148': ['grafika',
#   'eredeti',
#   'magyar',
#   'linóleummetszet',
#   'csendélet'],
#  'http://lod.sztaki.hu/data/item/9161': ['grafika',
#   'eredeti',
#   'magyar',
#   'iniciálé',
#   'címlap',
#   'montázs',
#   'könyvtervezés',
#   'tervezőgrafika'],
#  'http://lod.sztaki.hu/data/item/9175': ['grafika',
#   'eredeti',
#   'magyar',
#   'litográfia',
#   'életkép',
#   'emberábrázolás',
#   'illusztráció',
#   'Zola, Émile (1840-1902)',
#   'nőábrázolás'],
#  'http://lod.sztaki.hu/data/item/9189': ['grafika',
#   'eredeti',
#   'magyar',
#   'arckép',
#   'emberábrázolás',
#   'szénrajz'],
#  'http://lod.sztaki.hu/data/item/9191': ['grafika',
#   'eredeti',
#   'magyar',
#   'arckép',
#   'szénrajz',
#   'nőábrázolás'],
#  'http://lod.sztaki.hu/data/item/9238': ['grafika',
#   'eredeti',
#   'magyar',
#   'linóleummetszet',
#   'emberábrázolás',
#   'illusztráció',
#   'mitológiai ábrázolás',
#   'nőábrázolás'],
#  'http://lod.sztaki.hu/data/item/9241': ['grafika',
#   'eredeti',
#   'magyar',
#   'arckép',
#   'emberábrázolás',
#   'rézmetszet'],
#  'http://lod.sztaki.hu/data/item/9257': ['grafika',
#   'eredeti',
#   'magyar',
#   'arckép',
#   'szén',
#   'nőábrázolás']}

# %%
len(artworkssub)
# Out:
# 100

# %%
with open("ndhungarycol.tsv", "wt", encoding="utf-8-sig") as out_file:
  twriter = csv.writer(out_file, delimiter="\t")
  twriter.writerow(["artwork", "subjects"])
  for el in artworkssub:
    twriter.writerow([el, " @ ".join(artworkssub[el])])

# %% [markdown]
# ## Zeri

# %%
# zeri
variables = ["art", "subj_descr"]
zeri_query = """
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX fabio: <http://purl.org/spar/fabio/>


SELECT distinct ?art (GROUP_CONCAT(distinct ?subj_label; separator = " @ ") as ?subj_descr)
WHERE {
 
  # ?art a fabio:ArtisticWork. 
    # ?art fabio:hasSubjectTerm ?subj; rdfs:label ?art_label.
  # ?subj rdfs:label ?subj_label.
}
 GROUP BY ?art
 ORDER BY RAND()
 LIMIT 100

"""


recall = sample_selection("column_completeness_zer.csv", zer_query, zeri_endpoint, variables)

# %% [markdown]
# ## Nomisma

# %%
# nomisma
variables = ["art", "subj_descr"]
nomisma_query = """
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX dcmitype: <http://purl.org/dc/dcmitype/>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
PREFIX nm: <http://nomisma.org/id/>
PREFIX nmo: <http://nomisma.org/ontology#>
PREFIX org: <http://www.w3.org/ns/org#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>


SELECT DISTINCT ?art (GROUP_CONCAT(distinct ?subj_label; separator = " @ ") as ?subj_descr) WHERE {
  
 {?coin nmo:hasObverse ?art} UNION {?coin nmo:hasReverse ?art}
  # ?art nmo:hasPortrait ?subj.
  # ?subj skos:prefLabel ?subj_label.

  FILTER(lang(?subj_label)='en')
  
} GROUP BY ?art
ORDER BY RAND()
  LIMIT 100


"""


nomisma_recall = sample_selection("column_completeness_nomisma.csv", nomisma_query, nomisma_endpoint, variables)

# %% [markdown]
# ## Wikidata

# %%
# select all the qualifiers of wdt:P180
wd_constraint = []
wd_query_constr = """

SELECT DISTINCT ?qual {
  wd:P180 p:P2302 [ ps:P2302 wd:Q21510851 ; pq:P2306 ?constr] .   
  # ?constr wikibase:qualifier ?qual.                       
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en" }   
} ORDER BY ASC(xsd:integer(strafter(str(?prop), concat(str(wd:), "P"))))

"""

res = sparl_query_setting(wd_query_constr, wd_endpoint)

# manipulate the result
for result in res["results"]["bindings"]:
  constraint = "<"+result["qual"]["value"]+">"
  wd_constraint.append(constraint)

print(wd_constraint)
# Out:
# ['<http://www.wikidata.org/prop/qualifier/P18>', '<http://www.wikidata.org/prop/qualifier/P21>', '<http://www.wikidata.org/prop/qualifier/P127>', '<http://www.wikidata.org/prop/qualifier/P137>', '<http://www.wikidata.org/prop/qualifier/P144>', '<http://www.wikidata.org/prop/qualifier/P149>', '<http://www.wikidata.org/prop/qualifier/P155>', '<http://www.wikidata.org/prop/qualifier/P156>', '<http://www.wikidata.org/prop/qualifier/P175>', '<http://www.wikidata.org/prop/qualifier/P176>', '<http://www.wikidata.org/prop/qualifier/P180>', '<http://www.wikidata.org/prop/qualifier/P186>', '<http://www.wikidata.org/prop/qualifier/P276>', '<http://www.wikidata.org/prop/qualifier/P304>', '<http://www.wikidata.org/prop/qualifier/P407>', '<http://www.wikidata.org/prop/qualifier/P459>', '<http://www.wikidata.org/prop/qualifier/P462>', '<http://www.wikidata.org/prop/qualifier/P518>', '<http://www.wikidata.org/prop/qualifier/P560>', '<http://www.wikidata.org/prop/qualifier/P585>', '<http://www.wikidata.org/prop/qualifier/P642>', '<http://www.wikidata.org/prop/qualifier/P710>', '<http://www.wikidata.org/prop/qualifier/P1011>', '<http://www.wikidata.org/prop/qualifier/P1012>', '<http://www.wikidata.org/prop/qualifier/P1107>', '<http://www.wikidata.org/prop/qualifier/P1114>', '<http://www.wikidata.org/prop/qualifier/P1120>', '<http://www.wikidata.org/prop/qualifier/P1132>', '<http://www.wikidata.org/prop/qualifier/P1269>', '<http://www.wikidata.org/prop/qualifier/P1310>', '<http://www.wikidata.org/prop/qualifier/P1340>', '<http://www.wikidata.org/prop/qualifier/P1346>', '<http://www.wikidata.org/prop/qualifier/P1354>', '<http://www.wikidata.org/prop/qualifier/P1419>', '<http://www.wikidata.org/prop/qualifier/P1480>', '<http://www.wikidata.org/prop/qualifier/P1535>', '<http://www.wikidata.org/prop/qualifier/P1545>', '<http://www.wikidata.org/prop/qualifier/P1552>', '<http://www.wikidata.org/prop/qualifier/P1591>', '<http://www.wikidata.org/prop/qualifier/P1594>', '<http://www.wikidata.org/prop/qualifier/P1620>', '<http://www.wikidata.org/prop/qualifier/P1684>', '<http://www.wikidata.org/prop/qualifier/P1810>', '<http://www.wikidata.org/prop/qualifier/P1884>', '<http://www.wikidata.org/prop/qualifier/P1932>', '<http://www.wikidata.org/prop/qualifier/P2210>', '<http://www.wikidata.org/prop/qualifier/P2241>', '<http://www.wikidata.org/prop/qualifier/P2283>', '<http://www.wikidata.org/prop/qualifier/P2634>', '<http://www.wikidata.org/prop/qualifier/P2677>', '<http://www.wikidata.org/prop/qualifier/P2868>', '<http://www.wikidata.org/prop/qualifier/P2913>', '<http://www.wikidata.org/prop/qualifier/P3629>', '<http://www.wikidata.org/prop/qualifier/P3680>', '<http://www.wikidata.org/prop/qualifier/P3828>', '<http://www.wikidata.org/prop/qualifier/P3831>', '<http://www.wikidata.org/prop/qualifier/P4878>', '<http://www.wikidata.org/prop/qualifier/P4895>', '<http://www.wikidata.org/prop/qualifier/P5102>', '<http://www.wikidata.org/prop/qualifier/P5422>', '<http://www.wikidata.org/prop/qualifier/P5961>', '<http://www.wikidata.org/prop/qualifier/P6022>', '<http://www.wikidata.org/prop/qualifier/P6568>', '<http://www.wikidata.org/prop/qualifier/P7380>', '<http://www.wikidata.org/prop/qualifier/P7452>', '<http://www.wikidata.org/prop/qualifier/P8031>', '<http://www.wikidata.org/prop/qualifier/P8032>', '<http://www.wikidata.org/prop/qualifier/P8503>', '<http://www.wikidata.org/prop/qualifier/P8822>', '<http://www.wikidata.org/prop/qualifier/P8839>']

# %%
# this query can sometimes return timeout error
constr_values = " ".join(wd_constraint)
variables = ["art", "subj1", "constr", "qualifier", "subj2", "subj3"]
wd_query_constr = """

PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX pq: <http://www.wikidata.org/prop/qualifier/>
PREFIX ps: <http://www.wikidata.org/prop/statement/>
PREFIX p: <http://www.wikidata.org/prop/>

SELECT DISTINCT ?art (GROUP_CONCAT(distinct ?subj1 ; separator = " @ ") as ?subject1) ?subj_qualified (GROUP_CONCAT(distinct ?subj2; separator = " @ ") as ?subject2) (GROUP_CONCAT(distinct ?subj3; separator = " @ ") as ?subject3)  WHERE {
   VALUES ?constr {<http://www.wikidata.org/prop/qualifier/P18> <http://www.wikidata.org/prop/qualifier/P21> <http://www.wikidata.org/prop/qualifier/P127> <http://www.wikidata.org/prop/qualifier/P144> <http://www.wikidata.org/prop/qualifier/P149> <http://www.wikidata.org/prop/qualifier/P155> <http://www.wikidata.org/prop/qualifier/P156> <http://www.wikidata.org/prop/qualifier/P175> <http://www.wikidata.org/prop/qualifier/P176> <http://www.wikidata.org/prop/qualifier/P180> <http://www.wikidata.org/prop/qualifier/P186> <http://www.wikidata.org/prop/qualifier/P276> <http://www.wikidata.org/prop/qualifier/P304> <http://www.wikidata.org/prop/qualifier/P407> <http://www.wikidata.org/prop/qualifier/P459> <http://www.wikidata.org/prop/qualifier/P462> <http://www.wikidata.org/prop/qualifier/P518> <http://www.wikidata.org/prop/qualifier/P560> <http://www.wikidata.org/prop/qualifier/P585> <http://www.wikidata.org/prop/qualifier/P642> <http://www.wikidata.org/prop/qualifier/P710> <http://www.wikidata.org/prop/qualifier/P1011> <http://www.wikidata.org/prop/qualifier/P1012> <http://www.wikidata.org/prop/qualifier/P1107> <http://www.wikidata.org/prop/qualifier/P1114> <http://www.wikidata.org/prop/qualifier/P1120> <http://www.wikidata.org/prop/qualifier/P1132> <http://www.wikidata.org/prop/qualifier/P1269> <http://www.wikidata.org/prop/qualifier/P1310> <http://www.wikidata.org/prop/qualifier/P1340> <http://www.wikidata.org/prop/qualifier/P1346> <http://www.wikidata.org/prop/qualifier/P1354> <http://www.wikidata.org/prop/qualifier/P1419> <http://www.wikidata.org/prop/qualifier/P1480> <http://www.wikidata.org/prop/qualifier/P1535> <http://www.wikidata.org/prop/qualifier/P1545> <http://www.wikidata.org/prop/qualifier/P1552> <http://www.wikidata.org/prop/qualifier/P1591> <http://www.wikidata.org/prop/qualifier/P1594> <http://www.wikidata.org/prop/qualifier/P1620> <http://www.wikidata.org/prop/qualifier/P1684> <http://www.wikidata.org/prop/qualifier/P1810> <http://www.wikidata.org/prop/qualifier/P1884> <http://www.wikidata.org/prop/qualifier/P1932> <http://www.wikidata.org/prop/qualifier/P2210> <http://www.wikidata.org/prop/qualifier/P2241> <http://www.wikidata.org/prop/qualifier/P2283> <http://www.wikidata.org/prop/qualifier/P2634> <http://www.wikidata.org/prop/qualifier/P2677> <http://www.wikidata.org/prop/qualifier/P2868> <http://www.wikidata.org/prop/qualifier/P2913> <http://www.wikidata.org/prop/qualifier/P3629> <http://www.wikidata.org/prop/qualifier/P3680> <http://www.wikidata.org/prop/qualifier/P3828> <http://www.wikidata.org/prop/qualifier/P3831> <http://www.wikidata.org/prop/qualifier/P4878> <http://www.wikidata.org/prop/qualifier/P4895> <http://www.wikidata.org/prop/qualifier/P5102> <http://www.wikidata.org/prop/qualifier/P5422> <http://www.wikidata.org/prop/qualifier/P5961> <http://www.wikidata.org/prop/qualifier/P6022> <http://www.wikidata.org/prop/qualifier/P6568> <http://www.wikidata.org/prop/qualifier/P7380> <http://www.wikidata.org/prop/qualifier/P7452> <http://www.wikidata.org/prop/qualifier/P8031> <http://www.wikidata.org/prop/qualifier/P8032> <http://www.wikidata.org/prop/qualifier/P8503> <http://www.wikidata.org/prop/qualifier/P8822> <http://www.wikidata.org/prop/qualifier/P8839>}
   
   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
     {?art wdt:P31 wd:Q3305213} UNION {?art wdt:P31 wd:Q860861}
  # ?art wdt:P921 ?subj2; wdt:P1257 ?subj3.  
  # ?art p:P180 ?P180node . 
  # ?P180node ps:P180 ?subj1. 
  OPTIONAL {
   
    # ?P180node ?constr ?qualifier  
    BIND (CONCAT(?subj1, ?constr, ?qualifier) AS ?subj_qualified)
  }
} GROUP BY ?art ?subj_qualified
  # ORDER BY RAND()

  LIMIT 100
  

  """

recall = sample_selection("column_completeness_wd.csv", wd_query_constr, wd_endpoint, variables)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/SPARQLWrapper/Wrapper.py in _query(self)
#     925             else:
# --> 926                 response = urlopener(request)
#     927             return response, self.returnFormat
#
# /usr/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# /usr/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# /usr/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#
# /usr/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# /usr/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /usr/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 500: Internal Server Error
#
# During handling of the above exception, another exception occurred:
#
# EndPointInternalError                     Traceback (most recent call last)
# <ipython-input-12-44b38da8d2e8> in <module>()
#      29   """
#      30
# ---> 31 recall = sample_selection("column_completeness_wd.csv", wd_query_constr, wd_endpoint, variables)
#      32
#
# <ipython-input-8-9ec577006844> in sample_selection(csv_to_create, query, endpoint, var_list)
#       5     if os.stat(csv_to_create).st_size == 0:
#       6         my_file.writerow(var_list)
# ----> 7     res = sparl_query_setting(query, endpoint)
#       8     for result in res["results"]["bindings"]:
#       9       result_list = []
#
# <ipython-input-2-23da2ac34093> in sparl_query_setting(query, endpoint)
#       6   sparql.setReturnFormat(JSON)
#       7   # get the results
# ----> 8   results = sparql.query().convert()
#       9   return results
#
# /usr/local/lib/python3.7/dist-packages/SPARQLWrapper/Wrapper.py in query(self)
#     958         :rtype: :class:`QueryResult` instance
#     959         """
# --> 960         return QueryResult(self._query())
#     961
#     962     def queryAndConvert(self) -> "QueryResult.ConvertResult":
#
# /usr/local/lib/python3.7/dist-packages/SPARQLWrapper/Wrapper.py in _query(self)
#     936                 raise URITooLong(e.read())
#     937             elif e.code == 500:
# --> 938                 raise EndPointInternalError(e.read())
#     939             else:
#     940                 raise e
#
# EndPointInternalError: EndPointInternalError: The endpoint returned the HTTP status code 500.
#
# Response:
# b'SPARQL-QUERY: queryStr=\n\nPREFIX wd: <http://www.wikidata.org/entity/>\nPREFIX pq: <http://www.wikidata.org/prop/qualifier/>\nPREFIX ps: <http://www.wikidata.org/prop/statement/>\nPREFIX p: <http://www.wikidata.org/prop/>\n\nSELECT DISTINCT ?art (GROUP_CONCAT(distinct ?subj1 ; separator = " @ ") as ?subject1) ?subj_qualified (GROUP_CONCAT(distinct ?subj2; separator = " @ ") as ?subject2) (GROUP_CONCAT(distinct ?subj3; separator = " @ ") as ?subject3)  WHERE {\n   VALUES ?constr {<http://www.wikidata.org/prop/qualifier/P18> <http://www.wikidata.org/prop/qualifier/P21> <http://www.wikidata.org/prop/qualifier/P127> <http://www.wikidata.org/prop/qualifier/P144> <http://www.wikidata.org/prop/qualifier/P149> <http://www.wikidata.org/prop/qualifier/P155> <http://www.wikidata.org/prop/qualifier/P156> <http://www.wikidata.org/prop/qualifier/P175> <http://www.wikidata.org/prop/qualifier/P176> <http://www.wikidata.org/prop/qualifier/P180> <http://www.wikidata.org/prop/qualifier/P186> <http://www.wikidata.org/prop/qualifier/P276> <http://www.wikidata.org/prop/qualifier/P304> <http://www.wikidata.org/prop/qualifier/P407> <http://www.wikidata.org/prop/qualifier/P459> <http://www.wikidata.org/prop/qualifier/P462> <http://www.wikidata.org/prop/qualifier/P518> <http://www.wikidata.org/prop/qualifier/P560> <http://www.wikidata.org/prop/qualifier/P585> <http://www.wikidata.org/prop/qualifier/P642> <http://www.wikidata.org/prop/qualifier/P710> <http://www.wikidata.org/prop/qualifier/P1011>...

# %% [markdown]
# # Interlinking of artworks via owl:sameAs or similar

# %% [markdown]
# ## DBpedia

# %%
# How many artworks

queryalldb = '''
prefix dbo: <http://dbpedia.org/ontology/>
prefix dct: <http://purl.org/dc/terms/>
prefix dbp: <http://dbpedia.org/property/>
SELECT (COUNT(distinct ?artwork) as ?tot) WHERE {
# ?artwork a dbo:Artwork }'''

queryalldbres = sparl_query_setting(queryalldb, dbpedia)

for result in queryalldbres["results"]["bindings"]:
  print(result["tot"]["value"])
  tot = result["tot"]["value"]

# How many artworks linked with owl:sameAs?
queryowldb = '''
prefix owl: <http://www.w3.org/2002/07/owl#>
prefix dbo: <http://dbpedia.org/ontology/>
prefix dct: <http://purl.org/dc/terms/>
prefix dbp: <http://dbpedia.org/property/>
SELECT (COUNT(distinct ?artwork) as ?tot) WHERE {
# ?artwork a dbo:Artwork;
owl:sameAs ?x }'''

queryowldbres = sparl_query_setting(queryowldb, dbpedia)
for result in queryowldbres["results"]["bindings"]:
  print(result["tot"]["value"])
  owl = result["tot"]["value"]

print(int(owl)/int(tot))
# Out:
# 11678
# 11588
# 0.9922932008905635

# %%
dbpediainterlinkingscore = 0.9922932008905635

# %% [markdown]
# ## Europeana

# %%
# All artworks in europeana
queryalleuro = '''
PREFIX ore: <http://www.openarchives.org/ore/terms/>
PREFIX edm: <http://www.europeana.eu/schemas/edm/>

select  (COUNT(distinct ?CHO) as ?tot) where {
             # ?s a <http://www.w3.org/2004/02/skos/core#Concept> ;
<http://www.w3.org/2004/02/skos/core#broader>* <http://vocab.getty.edu/aat/300033618> .
# ?s2 a <http://www.w3.org/2004/02/skos/core#Concept>  ;
<http://www.w3.org/2004/02/skos/core#broader>* <http://vocab.getty.edu/aat/300047090> .
{?CHO dc:type ?s} UNION {?CHO dc:type ?s2}
}'''

resalle = sparl_query_setting(queryalleuro, euro)
for el in resalle["results"]["bindings"]:
  print(el["tot"]["value"])
  alleuro = el["tot"]["value"]
# All artworks in europeana related to another external artwork
queryrelatedeuro = '''PREFIX ore: <http://www.openarchives.org/ore/terms/>
PREFIX edm: <http://www.europeana.eu/schemas/edm/>

select  (count(distinct ?CHO) as ?tot) where {
             # ?s a <http://www.w3.org/2004/02/skos/core#Concept> ;
<http://www.w3.org/2004/02/skos/core#broader>* <http://vocab.getty.edu/aat/300033618> .
# ?s2 a <http://www.w3.org/2004/02/skos/core#Concept>  ;
<http://www.w3.org/2004/02/skos/core#broader>* <http://vocab.getty.edu/aat/300047090> .
{?CHO dc:type ?s;
dc:relation|edm:relatedTo ?x} UNION {?CHO dc:type ?s2;
dc:relation|edm:relatedTo ?x}
}'''

resrelatede = sparl_query_setting(queryrelatedeuro, euro)
for el in resrelatede["results"]["bindings"]:
  print(el["tot"]["value"])
  eurorelated = el["tot"]["value"]

print(int(eurorelated)/int(alleuro))
# Out:
# 13861
# 101
# 0.007286631556164779

# %%
europeanainterscore = 0.007286631556164779

# %% [markdown]
# ## Yago

# %%
qy4all = '''
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>

SELECT (count(distinct ?artwork) as ?tot)
WHERE {
  VALUES ?art {schema:Painting schema:Sculpture}
  # ?artwork rdf:type ?art }'''

ry4all = sparl_query_setting(qy4all, yago)

for el in ry4all["results"]["bindings"]:
  print(el["tot"]["value"])
  totalyago = int(el["tot"]["value"])

qy4owl = '''
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>

SELECT (count(distinct ?artwork) as ?tot)
WHERE {
  VALUES ?art {schema:Painting schema:Sculpture}
  # ?artwork rdf:type ?art;
  owl:sameAs ?something }'''

ry4owl = sparl_query_setting(qy4owl, yago)
for el in ry4owl["results"]["bindings"]:
  totalowl = int(el["tot"]["value"])
  print(totalowl)

print(totalowl/totalyago)
# Out:
# 29324
# 29324
# 1.0

# %%
yagointerlinkingscore = 1

# %% [markdown]
# ## ND Hungary
#
# Does not have any owl:sameAs / related property

# %%
listofproperties = '''PREFIX dc: <http://purl.org/dc/terms/>
SELECT distinct ?p WHERE { ?URI dc:type ?type;
# ?p ?o
FILTER (?type = "painting" || ?type  = "sculpture")} LIMIT 100'''

propertiesofndhungary = sparl_query_setting(listofproperties, nd_hungary)

for el in propertiesofndhungary["results"]["bindings"]:
  print(el["p"]["value"])
# Out:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/01/rdf-schema#label
# http://purl.org/dc/terms/title
# http://purl.org/dc/terms/description
# http://purl.org/dc/terms/date
# http://purl.org/dc/terms/identifier
# http://purl.org/dc/terms/format
# http://purl.org/dc/terms/publisher
# http://purl.org/dc/terms/creator
# http://purl.org/dc/terms/type

# %%
ndinterlinkingscore = 0

# %% [markdown]
# ## Arco

# %%
arco_query = """

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX arco-cd: <https://w3id.org/arco/ontology/context-description/>
PREFIX arco: <https://w3id.org/arco/ontology/arco/>

SELECT (count (distinct ?s) as ?tot) 
WHERE {
# ?s a arco:HistoricOrArtisticProperty. 
# ?s  owl:sameAs | rdfs:seeAlso ?resource. 
}
"""



res = sparl_query_setting(arco_query, arco_endpoint)

# manipulate the result
for result in res["results"]["bindings"]:
    print(result["tot"]["value"])
# Out:
# 5447

# %% [markdown]
# ## Zeri

# %%
zeri_query = """

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX fabio: <http://purl.org/spar/fabio/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>

SELECT (count (distinct ?artwork) as ?tot) WHERE {
  # ?artwork a fabio:ArtisticWork; 
  owl:sameAs | rdfs:seeAlso ?resource. 
} 


"""

res = sparl_query_setting(zeri_query, zeri_endpoint)

# manipulate the result
for result in res["results"]["bindings"]:
    print(result["tot"]["value"])
# Out:
# 11

# %% [markdown]
# ## Nomisma

# %%
nomisma_query = """
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX dcmitype: <http://purl.org/dc/dcmitype/>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
PREFIX nm: <http://nomisma.org/id/>
PREFIX nmo: <http://nomisma.org/ontology#>
PREFIX org: <http://www.w3.org/ns/org#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>


SELECT (count(distinct ?art) as ?tot_art) WHERE {
 
  {?coin nmo:hasObverse ?art} UNION {?coin nmo:hasReverse ?art}
  # ?coin owl:sameAs ?resource. 
} 


"""

res = sparl_query_setting(nomisma_query, nomisma_endpoint)

# manipulate the result
for result in res["results"]["bindings"]:
  print(result["tot_art"]["value"])
# Out:
# 0

# %% [markdown]
# ## Wikidata
# Since Wikidata don't use owl:sameAs to connect resources, but specific relations for every institution, we select xxx properties to evaluate interlinking.

# %%
wd_query = """
SELECT (count(distinct ?something) as ?tot) WHERE {
VALUES ?class { wd:Q3305213 wd:Q860861 }
# ?something wdt:P31 ?class ;
           wikibase:identifiers ?ident .
FILTER (?ident > 0)
}
"""

res = sparl_query_setting(wd_query, wd_endpoint)

# manipulate the result
for result in res["results"]["bindings"]:
  print(result["tot"]["value"])
# Out:
# 414678

# %% [markdown]
# Sari

# %%
sari_query = """
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX getty: <http://vocab.getty.edu/ontology#>
PREFIX gndo: <https://d-nb.info/standards/elementset/gnd#>

SELECT (count(distinct ?a) as ?tot) WHERE {
VALUES ?type{"""+artwork_types+"""}
  # ?a a gndo:Work; 
     gndo:formOfWorkAndExpression ?type; 
  owl:sameAs ?resource. 


} 

"""

res = sparl_query_setting(sari_query, sari_endpoint)

# manipulate the result

for result in res["results"]["bindings"]:
 print(result["tot"]["value"])
# Out:
# 338

# %% [markdown]
# # Reference to external taxonomy (Iconclass/Getty)

# %% [markdown]
# ## DBpedia, Yago, ND Hungary, Museum Finland

# %%
# not linked to iconclass or aat
dbpediataxonomyscore = 0
yagotaxonomyscore = 0
ndhungarytaxonomyscore = 0
museumfinlandtaxonomyscore = 0

# %% [markdown]
# ## Europeana

# %%
querytaxonomy = '''PREFIX ore: <http://www.openarchives.org/ore/terms/>
PREFIX edm: <http://www.europeana.eu/schemas/edm/>

select  (count(distinct ?CHO) as ?tot) where {
             # ?s a <http://www.w3.org/2004/02/skos/core#Concept> ;
<http://www.w3.org/2004/02/skos/core#broader>* <http://vocab.getty.edu/aat/300033618> .
# ?s2 a <http://www.w3.org/2004/02/skos/core#Concept>  ;
<http://www.w3.org/2004/02/skos/core#broader>* <http://vocab.getty.edu/aat/300047090> .

{?CHO dc:type ?s;
dc:subject ?sub .
FILTER (STRSTARTS(str(?sub), "http://iconclass"))}

UNION 

{?CHO dc:type ?s2;
dc:subject ?sub .
FILTER (STRSTARTS(str(?sub), "http://iconclass"))}
}'''

querytaxonomyres = sparl_query_setting(querytaxonomy, euro)

for el in querytaxonomyres["results"]["bindings"]:
  print(el["tot"]["value"])
  europeanataxonomy = int(el["tot"]["value"])


print(europeanataxonomy/int(alleuro))
# Out:
# 905
# 0.06529110453791213

# %%
europeanaiconclasstaxscore = 0.06529110453791213
europeanaaatscore = 1 #all the paintings and sculptures are retrieved using AAT

# %% [markdown]
# ## Arco

# %%
arco_query = """

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX arco-cd: <https://w3id.org/arco/ontology/context-description/>
PREFIX arco: <https://w3id.org/arco/ontology/arco/>

SELECT (count (distinct ?s) as ?tot) 
WHERE {
# ?s a arco:HistoricOrArtisticProperty; 
  arco-cd:iconclassCode ?resource. 
}
"""



res = sparl_query_setting(arco_query, arco_endpoint)

# manipulate the result
for result in res["results"]["bindings"]:
    print(result["tot"]["value"])
# Out:
# 261531

# %% [markdown]
# ## Zeri

# %%
zeri_query = """

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX fabio: <http://purl.org/spar/fabio/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>

SELECT (count (distinct ?artwork) as ?tot) WHERE {
  # ?artwork rdf:type fabio:ArtisticWork; 
  fabio:hasSubjectTerm ?subj.
  # ?subj rdfs:seeAlso ?resource. 
  FILTER (regex(str(?resource), "iconclass", "i"))
}


"""

res = sparl_query_setting(zeri_query, zeri_endpoint)

# manipulate the result
for result in res["results"]["bindings"]:
    print(result["tot"]["value"])
# Out:
# 10943

# %% [markdown]
# ## Nomisma
# It has links only to Getty Vocabularies, none to Iconclass

# %%
# subjects relation exploration

nomisma_query = """
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX dcmitype: <http://purl.org/dc/dcmitype/>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
PREFIX nm: <http://nomisma.org/id/>
PREFIX nmo: <http://nomisma.org/ontology#>
PREFIX org: <http://www.w3.org/ns/org#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>


SELECT (count(distinct ?obj) as ?tot) WHERE {
 
  # ?sub nmo:hasPortrait ?obj.
  # ?obj skos:exactMatch ?obj2. 
  FILTER(regex(str(?obj2), "getty", "i"))
 
} 


"""

res = sparl_query_setting(nomisma_query, nomisma_endpoint)

# manipulate the result
for result in res["results"]["bindings"]:
  print(result["tot"]["value"])
# Out:
# 39

# %% [markdown]
# Wikidata

# %%
# wikidata. Number of paintings and sculptures having an iconclass code directly associated


wd_query = """

SELECT (count(distinct ?art) as ?tot) WHERE {
  {?art wdt:P31 wd:Q3305213} UNION {?art wdt:P31 wd:Q860861}
 
  VALUES ?rel {wdt:P1256 wdt:P5986}
{
  # ?art (wdt:P180 | wdt:P921) ?subj.
  # ?subj ?rel ?resource. 
  }
  UNION 
{
  # ?art wdt:P1257 ?resource.
  
}
} 

"""

res = sparl_query_setting(wd_query, wd_endpoint)

# manipulate the result
for result in res["results"]["bindings"]:
  print(result["tot"]["value"])
# Out:
# 74213

# %% [markdown]
# ## SARI
# We runned the same query looking for "Getty" and "Iconclass" presence in the results through a regex.

# %%
sari_query = """
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX getty: <http://vocab.getty.edu/ontology#>
PREFIX gndo: <https://d-nb.info/standards/elementset/gnd#>

SELECT (count (distinct ?a) as ?tot) WHERE {
VALUES ?type{"""+artwork_types+"""}
  # ?a a gndo:Work; 
     gndo:formOfWorkAndExpression ?type; 
     # ?rel ?resource.

FILTER(regex(str(?resource), "iconclass", "i"))


} LIMIT 100

"""

res = sparl_query_setting(sari_query, sari_endpoint)

# manipulate the result

for result in res["results"]["bindings"]:
 print(result["tot"]["value"])
# Out:
# 0

# %% [markdown]
# # Intra-interlinking

# %% [markdown]
# ## DBpedia

# %%
intrainterlinkingpotentialdb = '''prefix dbo: <http://dbpedia.org/ontology/>
prefix dct: <http://purl.org/dc/terms/>
prefix dbp: <http://dbpedia.org/property/>
SELECT (AVG(?no) AS ?avg) 
WHERE { 
 SELECT (COUNT(distinct ?instance) AS ?no) 
 WHERE { ?instance a dbo:Artwork ;
dbp:subject|dct:subject ?subject }
GROUP BY ?subject
}'''

iilpresdb = sparl_query_setting(intrainterlinkingpotentialdb, dbpedia)

for el in iilpresdb["results"]["bindings"]:
  print(el["avg"]["value"])
  iilpdbscore = el["avg"]["value"]
# Out:
# 4.173305056663795

# %%
subjectmorethan1db = '''prefix dbo: <http://dbpedia.org/ontology/>
prefix dct: <http://purl.org/dc/terms/>
prefix dbp: <http://dbpedia.org/property/>
SELECT (COUNT(distinct ?subject) as ?tot)
WHERE { FILTER (?no > 1) {
 SELECT ?subject (COUNT(distinct ?instance) AS ?no) 
 WHERE { ?instance a dbo:Artwork ;
dbp:subject|dct:subject ?subject }
GROUP BY ?subject }
}'''

allsubsuridb = '''prefix dbo: <http://dbpedia.org/ontology/>
prefix dct: <http://purl.org/dc/terms/>
prefix dbp: <http://dbpedia.org/property/>
 SELECT (COUNT(distinct ?subject) as ?tot)
 WHERE { ?instance a dbo:Artwork ;
dbp:subject|dct:subject ?subject
FILTER (isURI(?subject)) }'''

submorethan1dbres = sparl_query_setting(subjectmorethan1db, dbpedia)
allsubsuridbres = sparl_query_setting(allsubsuridb, dbpedia)

for el in submorethan1dbres["results"]["bindings"]:
  submorethan1dbvalue = int(el["tot"]["value"])

allsubsuridbvalue = int(allsubsuridbres["results"]["bindings"][0]["tot"]["value"])

intralinkingdb = submorethan1dbvalue/allsubsuridbvalue
print(intralinkingdb)
# Out:
# 0.40480866915001695

# %% [markdown]
# ## Europeana

# %%
subjectmorethan1euro = '''
PREFIX ore: <http://www.openarchives.org/ore/terms/>
PREFIX edm: <http://www.europeana.eu/schemas/edm/>
SELECT (count(?sub) as ?tot) WHERE { FILTER (?tot > 1) {
select  ?sub (count(distinct ?CHO) as ?tot) where {
             # ?s a <http://www.w3.org/2004/02/skos/core#Concept> ;
<http://www.w3.org/2004/02/skos/core#broader>* <http://vocab.getty.edu/aat/300033618> .
# ?s2 a <http://www.w3.org/2004/02/skos/core#Concept>  ;
<http://www.w3.org/2004/02/skos/core#broader>* <http://vocab.getty.edu/aat/300047090> .

{?CHO dc:type ?s;
dc:subject ?sub .}

UNION 

{?CHO dc:type ?s2;
dc:subject ?sub .}
}
GROUP BY ?sub }
}'''

allsubjectseuro = '''
PREFIX ore: <http://www.openarchives.org/ore/terms/>
PREFIX edm: <http://www.europeana.eu/schemas/edm/>
SELECT (count(distinct ?sub) as ?tot) WHERE {
             # ?s a <http://www.w3.org/2004/02/skos/core#Concept> ;
<http://www.w3.org/2004/02/skos/core#broader>* <http://vocab.getty.edu/aat/300033618> .
# ?s2 a <http://www.w3.org/2004/02/skos/core#Concept>  ;
<http://www.w3.org/2004/02/skos/core#broader>* <http://vocab.getty.edu/aat/300047090> .

{?CHO dc:type ?s;
dc:subject ?sub .
FILTER (isURI(?sub))}

UNION 

{?CHO dc:type ?s2;
dc:subject ?sub .
FILTER(isURI(?sub))}
}'''

allseurores = sparl_query_setting(allsubjectseuro, euro)
allseuroresvalue = int(allseurores["results"]["bindings"][0]["tot"]["value"])
smorethan1eurores = sparl_query_setting(subjectmorethan1euro, euro)
smorethan1eurovalue = int(smorethan1eurores["results"]["bindings"][0]["tot"]["value"])

intralinkingeuro = smorethan1eurovalue/allseuroresvalue
print(intralinkingeuro)
# Out:
# 0.6122093023255814

# %% [markdown]
# ## Yago

# %%
subjectmorethan1yago = '''
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>
SELECT (count(distinct ?sub) as ?tot) WHERE { FILTER (?tot > 1) {
SELECT ?sub (count(distinct ?artwork) as ?tot)
WHERE {
  VALUES ?art {schema:Painting schema:Sculpture}
  # ?artwork rdf:type ?art ;
schema:about ?sub .
    } GROUP BY ?sub } }'''

allsubjectsyago = '''
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>
SELECT (count(distinct ?sub) as ?tot)
WHERE {
  VALUES ?art {schema:Painting schema:Sculpture}
  # ?artwork rdf:type ?art ;
schema:about ?sub .
  FILTER (isURI(?sub))
    }'''

allsyagores = sparl_query_setting(allsubjectsyago, yago)
allsyagoresvalue = int(allsyagores["results"]["bindings"][0]["tot"]["value"])
smorethan1yagores = sparl_query_setting(subjectmorethan1yago, yago)
smorethan1yagovalue = int(smorethan1yagores["results"]["bindings"][0]["tot"]["value"])

intralinkingyago = smorethan1yagovalue/allsyagoresvalue
print(intralinkingyago)
# Out:
# 0.16753536857781087

# %% [markdown]
# ## ND Hungary
#
# ND Hungary has no subjects or iconoraphic/iconologic related elements expressed by URIs, therefore its intra interlinking potential is 0

# %%
iilpyndhungary = 0

# %% [markdown]
# ## ARCO

# %%
# number of subjects present in more than one artwork/tot. number of subj. 
intrainterlinkingpotentialarco = '''
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX arco-cd: <https://w3id.org/arco/ontology/context-description/>
PREFIX arco-d: <https://w3id.org/arco/ontology/denotative-description/>
PREFIX arco: <https://w3id.org/arco/ontology/arco/>

SELECT (COUNT(distinct ?sub) as ?tot)
WHERE { FILTER (?no > 1) {
 SELECT ?sub (COUNT(distinct ?artwork) AS ?no) 
 WHERE { ?artwork (arco-cd:hasSubject | arco-d:hasIconographicOrDecorativeApparatus) ?sub. 
# ?artwork a arco:HistoricOrArtisticProperty.}
GROUP BY ?sub }
}


  '''
iilpyarcores = sparl_query_setting(intrainterlinkingpotentialarco, arco_endpoint)

for el in iilpyarcores["results"]["bindings"]:
  subarcoscore = el["tot"]["value"]
  print(subpyarcoscore)
# Out:
# 41947

# %%
# tot num of subj
intrainterlinkingpotentialarco = '''
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX arco-cd: <https://w3id.org/arco/ontology/context-description/>
PREFIX arco-d: <https://w3id.org/arco/ontology/denotative-description/>
PREFIX arco: <https://w3id.org/arco/ontology/arco/>

SELECT (COUNT(distinct ?sub) as ?tot) where {
# ?artwork (arco-cd:hasSubject | arco-d:hasIconographicOrDecorativeApparatus) ?sub. 
# ?artwork a arco:HistoricOrArtisticProperty.

}


  '''
iilpyarcores = sparl_query_setting(intrainterlinkingpotentialarco, arco_endpoint)

for el in iilpyarcores["results"]["bindings"]:
  totarcoscore = el["tot"]["value"]
  print(totarcoscore)
# Out:
# 242506

# %%
s_intra = 41947/242506
print(s_intra)
# Out:
# 0.1729730398423132

# %% [markdown]
# ## Zeri

# %%
# number of subjects present in more than one artwork/tot. number of subj. 
intrainterlinkingpotentialzeri = '''
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX oaentry: <http://purl.org/emmedi/oaentry/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX fabio: <http://purl.org/spar/fabio/>

SELECT (COUNT(distinct ?sub) as ?tot)
WHERE { FILTER (?no > 1) {
 SELECT ?sub (COUNT(distinct ?artwork) AS ?no) 
 WHERE { ?artwork fabio:hasSubjectTerm ?sub; a fabio:ArtisticWork.
 }
GROUP BY ?sub }
}


  '''
iilpyarcores = sparl_query_setting(intrainterlinkingpotentialzeri, zeri_endpoint)

for el in iilpyarcores["results"]["bindings"]:
  subzeriscore = el["tot"]["value"]
  print(subzeriscore)
# Out:
# 1926

# %%
# tot num of subj
intrainterlinkingpotentialzeri = '''
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX oaentry: <http://purl.org/emmedi/oaentry/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX fabio: <http://purl.org/spar/fabio/>


 SELECT (COUNT(distinct ?sub) AS ?tot) 
 WHERE { ?artwork fabio:hasSubjectTerm ?sub; a fabio:ArtisticWork.
 }

  '''
iilpyarcores = sparl_query_setting(intrainterlinkingpotentialzeri, zeri_endpoint)

for el in iilpyarcores["results"]["bindings"]:
  totzeriscore = el["tot"]["value"]
  print(totzeriscore)

s_intra = int(subzeriscore)/int(totzeriscore)
print(s_intra)
# Out:
# 7232
# 0.2663163716814159

# %% [markdown]
# ## Nomisma

# %%
# number of subjects present in more than one artwork/tot. number of subj. 
intrainterlinkingpotentialnomisma = '''
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX dcmitype: <http://purl.org/dc/dcmitype/>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
PREFIX nm: <http://nomisma.org/id/>
PREFIX nmo: <http://nomisma.org/ontology#>
PREFIX org: <http://www.w3.org/ns/org#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT (COUNT(distinct ?sub) as ?tot)
WHERE { FILTER (?no > 1) {
 SELECT ?sub (COUNT(distinct ?artwork) AS ?no) 
 WHERE {    
   {?coin nmo:hasObverse ?artwork} UNION {?coin nmo:hasReverse ?artwork}
  # ?artwork nmo:hasPortrait ?sub.
 }
GROUP BY ?sub }
}


  '''
res = sparl_query_setting(intrainterlinkingpotentialnomisma, nomisma_endpoint)

for el in res["results"]["bindings"]:
  subnomismascore = int(el["tot"]["value"])
  print(subnomismascore)
# Out:
# 359

# %%
# number of subjects present in more than one artwork/tot. number of subj. 
intrainterlinkingpotentialnomisma = '''
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX dcmitype: <http://purl.org/dc/dcmitype/>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
PREFIX nm: <http://nomisma.org/id/>
PREFIX nmo: <http://nomisma.org/ontology#>
PREFIX org: <http://www.w3.org/ns/org#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT (COUNT(distinct ?sub) as ?tot) 
 WHERE {    
   {?coin nmo:hasObverse ?artwork} UNION {?coin nmo:hasReverse ?artwork}
  # ?artwork nmo:hasPortrait ?sub.
 }



  '''
res = sparl_query_setting(intrainterlinkingpotentialnomisma, nomisma_endpoint)

for el in res["results"]["bindings"]:
  totnomismascore = int(el["tot"]["value"])
  print(totnomismascore)
s_intra= subnomismascore/totnomismascore
print(s_intra)
# Out:
# 479
# 0.7494780793319415

# %% [markdown]
# ## Wikidata

# %%
# number of subjects present in more than one artwork/tot. number of subj. 
intrainterlinkingpotentialwd1 = '''

SELECT (COUNT(distinct ?sub) as ?tot)
WHERE { FILTER (?no > 1) {
 SELECT ?sub (COUNT(distinct ?artwork) AS ?no) 
 WHERE {    
  {?artwork wdt:P31 wd:Q3305213} UNION {?artwork wdt:P31 wd:Q860861}
  # ?artwork wdt:P180 | wdt:P921 | wdt:P1257 ?sub.
 }
GROUP BY ?sub }
}


  '''
res = sparl_query_setting(intrainterlinkingpotentialwd1, wd_endpoint)

for el in res["results"]["bindings"]:
  subwdscore = int(el["tot"]["value"])
  print(subwdscore)

intrainterlinkingpotentialwd2 = '''

SELECT (COUNT(distinct ?sub) as ?tot)
 WHERE {    
  {?artwork wdt:P31 wd:Q3305213} UNION {?artwork wdt:P31 wd:Q860861}
  # ?artwork wdt:P180 | wdt:P921 | wdt:P1257 ?sub.
 }



  '''
res2 = sparl_query_setting(intrainterlinkingpotentialwd2, wd_endpoint)

for el in res2["results"]["bindings"]:
  totwdscore = int(el["tot"]["value"])
  print(totwdscore)

s_intra= subwdscore/totwdscore
print(s_intra)
# Out:
# 14839
# 43195
# 0.3435351313809469

# %% [markdown]
# ## SARI

# %%
artwork_types= """<https://d-nb.info/gnd/4046277-8> <https://d-nb.info/gnd/4127900-1> <https://d-nb.info/gnd/4036042-8> <https://d-nb.info/gnd/4010427-8> <https://d-nb.info/gnd/4124432-1> <https://d-nb.info/gnd/4123412-1> <https://d-nb.info/gnd/4131808-0> <https://d-nb.info/gnd/4124432-1> <https://d-nb.info/gnd/4114333-4> <https://d-nb.info/gnd/4033760-1> <https://d-nb.info/gnd/4002511-1> <https://d-nb.info/gnd/4627787-0> <https://d-nb.info/gnd/4029783-4> <https://d-nb.info/gnd/4006627-7> <https://d-nb.info/gnd/4064542-3> <https://d-nb.info/gnd/4229053-3>"""

# %%
# number of subjects present in more than one artwork/tot. number of subj. 
intrainterlinkingpotentialsari1 = """

SELECT (COUNT(distinct ?sub) as ?tot)
WHERE { FILTER (?no > 1) {
 SELECT ?sub (COUNT(distinct ?artwork) AS ?no) 
 WHERE {    
VALUES ?type {<https://d-nb.info/gnd/4046277-8> <https://d-nb.info/gnd/4127900-1> <https://d-nb.info/gnd/4036042-8> <https://d-nb.info/gnd/4010427-8> <https://d-nb.info/gnd/4124432-1> <https://d-nb.info/gnd/4123412-1> <https://d-nb.info/gnd/4131808-0> <https://d-nb.info/gnd/4124432-1> <https://d-nb.info/gnd/4114333-4> <https://d-nb.info/gnd/4033760-1> <https://d-nb.info/gnd/4002511-1> <https://d-nb.info/gnd/4627787-0> <https://d-nb.info/gnd/4029783-4> <https://d-nb.info/gnd/4006627-7> <https://d-nb.info/gnd/4064542-3> <https://d-nb.info/gnd/4229053-3>}
  # ?artwork gndo:formOfWorkAndExpression ?type.
   # ?artwork  gndo:topic | gndo:gndSubjectCategory ?sub.
 }
GROUP BY ?sub }
}
  
"""
# res: 9

res = sparl_query_setting(intrainterlinkingpotentialsari1, sari_endpoint)

for el in res["results"]["bindings"]:
  subsariscore = int(el["tot"]["value"])
  print(subsariscore)

intrainterlinkingpotentialsari2 = '''

SELECT (COUNT(distinct ?sub) as ?tot)
 WHERE {    
VALUES ?type {'''+artwork_types+'''}
  # ?artwork gndo:formOfWorkAndExpression ?type.
   # ?artwork  (gndo:topic | gndo:gndSubjectCategory) ?sub.
 }



  '''
res2 = sparl_query_setting(intrainterlinkingpotentialsari2, sari_endpoint)
# res: 18 
for el in res2["results"]["bindings"]:
  totsariscore = int(el["tot"]["value"])
  print(totwdscore)

s_intra= subsariscore/totsariscore
print(s_intra)
# s_intra = 0,5
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/SPARQLWrapper/Wrapper.py in _query(self)
#     925             else:
# --> 926                 response = urlopener(request)
#     927             return response, self.returnFormat
#
# /usr/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# /usr/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# /usr/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#
# /usr/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# /usr/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /usr/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 500: Server Error
#
# During handling of the above exception, another exception occurred:
#
# EndPointInternalError                     Traceback (most recent call last)
# <ipython-input-26-77565ddb74a4> in <module>()
#      16
#      17
# ---> 18 res = sparl_query_setting(intrainterlinkingpotentialsari1, sari_endpoint)
#      19
#      20 for el in res["results"]["bindings"]:
#
# <ipython-input-3-deaa5558a2fc> in sparl_query_setting(query, endpoint)
#       6   sparql.setReturnFormat(JSON)
#       7   # get the results
# ----> 8   results = sparql.query().convert()
#       9   return results
#      10
#
# /usr/local/lib/python3.7/dist-packages/SPARQLWrapper/Wrapper.py in query(self)
#     958         :rtype: :class:`QueryResult` instance
#     959         """
# --> 960         return QueryResult(self._query())
#     961
#     962     def queryAndConvert(self) -> "QueryResult.ConvertResult":
#
# /usr/local/lib/python3.7/dist-packages/SPARQLWrapper/Wrapper.py in _query(self)
#     936                 raise URITooLong(e.read())
#     937             elif e.code == 500:
# --> 938                 raise EndPointInternalError(e.read())
#     939             else:
#     940                 raise e
#
# EndPointInternalError: EndPointInternalError: The endpoint returned the HTTP status code 500.
#
# Response:
# b"\nSPARQL-QUERY: queryStr=\n\nSELECT (COUNT(distinct ?sub) as ?tot)\nWHERE { FILTER (?no > 1) {\n SELECT ?sub (COUNT(distinct ?artwork) AS ?no) \n WHERE {    \nVALUES ?type {<https://d-nb.info/gnd/4046277-8> <https://d-nb.info/gnd/4127900-1> <https://d-nb.info/gnd/4036042-8> <https://d-nb.info/gnd/4010427-8> <https://d-nb.info/gnd/4124432-1> <https://d-nb.info/gnd/4123412-1> <https://d-nb.info/gnd/4131808-0> <https://d-nb.info/gnd/4124432-1> <https://d-nb.info/gnd/4114333-4> <https://d-nb.info/gnd/4033760-1> <https://d-nb.info/gnd/4002511-1> <https://d-nb.info/gnd/4627787-0> <https://d-nb.info/gnd/4029783-4> <https://d-nb.info/gnd/4006627-7> <https://d-nb.info/gnd/4064542-3> <https://d-nb.info/gnd/4229053-3>}\n  ?artwork gndo:formOfWorkAndExpression ?type.\n   ?artwork  gndo:topic | gndo:gndSubjectCategory ?sub.\n }\nGROUP BY ?sub }\n}\n  \n\njava.util.concurrent.ExecutionException: org.openrdf.query.MalformedQueryException: com.bigdata.rdf.sail.sparql.ast.VisitorException: QName 'gndo:formOfWorkAndExpression' uses an undefined prefix\n\tat java.util.concurrent.FutureTask.report(FutureTask.java:122)\n\tat java.util.concurrent.FutureTask.get(FutureTask.java:192)\n\tat com.bigdata.rdf.sail.webapp.BigdataServlet.submitApiTask(BigdataServlet.java:295)\n\tat com.bigdata.rdf.sail.webapp.QueryServlet.doSparqlQuery(QueryServlet.java:653)\n\tat com.bigdata.rdf.sail.webapp.QueryServlet.doGet(QueryServlet.java:288)\n\tat com.bigdata.rdf.sail.webapp.RESTServlet.doGet(RESTServlet.java...
